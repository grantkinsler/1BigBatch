# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.spatial import distance
from scipy.stats.mstats import gmean
# %matplotlib inline
from itertools import combinations
from itertools import chain
import sys
import os
import copy
sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

fgm_simulation_path = '/Users/grantkinsler/Documents/Stanford/Research/StarryNight/Git/starry-night/Simulations/FGM_simulation_callable.py'
sys.path.append(os.path.dirname(os.path.expanduser(fgm_simulation_path)))
from FGM_simulation_callable import simulation, nball_pull, gaussian_fitness

tools_path = '../code/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools

# %%
np.random.seed(953527608) # for exact figure reproducibility use this seed

# %%
fitness_data = p.read_csv('../data/DoubleBC_Merged_Fitness_Atish_Default_AllConditions.csv')
fitness_data = p.read_csv('../data/DoubleBC_Merged_Fitness_Atish_Weighted_Default_AllConditions_IncludingOld_swapsremoved.csv')

# %%
fitness_data = fitness_data.replace([np.inf, -np.inf], np.nan).dropna()

# %%
fitness_data
# Out:
#      barcode            gene                type        ploidy  \
# 0         53         Diploid             Diploid       Diploid
# 1        151            IRA1         stop_gained       Haploid
# 2        262    NotSequenced        NotSequenced  NotSequenced
# 3        273            IRA1  frameshift_variant       Haploid
# 4        323    NotSequenced        NotSequenced  NotSequenced
# 8        689            IRA1  frameshift_variant       Haploid
# 9        697    NotSequenced        NotSequenced  NotSequenced
# 12      1379    NotSequenced        NotSequenced  NotSequenced
# 13      1488    NotSequenced        NotSequenced  NotSequenced
# 14      1564         Diploid             Diploid       Diploid
# 15      1617            PDE2  frameshift_variant       Haploid
# 16      1641           other               other         other
# 18      1866            PDE2         stop_gained       Haploid
# 19      2037         Diploid             Diploid       Diploid
# 20      2039  Diploid + IRA2  frameshift_variant       Diploid
# 21      2288            GPB2         stop_gained       Haploid
# 22      2468            IRA2    missense_variant       Haploid
# 23      2608            GPB1  frameshift_variant       Haploid
# 24      2768            GPB2         stop_gained       Haploid
# 26      2808         Diploid             Diploid       Diploid
# 28      3250    NotSequenced        NotSequenced  NotSequenced
# 30      3379         Diploid             Diploid       Diploid
# 33      3577  Diploid + IRA2    missense_variant       Diploid
# 34      3585         Diploid             Diploid       Diploid
# 35      3675            IRA1    missense_variant       Haploid
# 36      3730    NotSequenced        NotSequenced  NotSequenced
# 37      3920         Diploid             Diploid       Diploid
# 38      4418         Diploid             Diploid       Diploid
# 39      4691         Diploid             Diploid       Diploid
# 40      4791         Diploid             Diploid       Diploid
# ..       ...             ...                 ...           ...
# 445   237576         Diploid             Diploid       Diploid
# 449   244443         Diploid             Diploid       Diploid
# 453   251379    NotSequenced        NotSequenced  NotSequenced
# 454   254044           other               other         other
# 456   258539         Diploid             Diploid       Diploid
# 457   261861         Diploid             Diploid       Diploid
# 458   262917           other               other         other
# 460   266802         Diploid             Diploid       Diploid
# 461   270104           other               other         other
# 463   276407           other               other         other
# 470   295458         Diploid             Diploid       Diploid
# 475   303501           other               other         other
# 476   304483           other               other         other
# 479   309655            PDE2  frameshift_variant       Haploid
# 480   310209         Diploid             Diploid       Diploid
# 483   317672         Diploid             Diploid       Diploid
# 485   328579         Diploid             Diploid       Diploid
# 486   329774         Diploid             Diploid       Diploid
# 487   330943           other               other         other
# 491   336972            SCH9    missense_variant       Haploid
# 492   338908         Diploid             Diploid       Diploid
# 493   340123    NotSequenced        NotSequenced  NotSequenced
# 496   349198    NotSequenced        NotSequenced  NotSequenced
# 503   375115         Diploid             Diploid       Diploid
# 505   379777            IRA2    missense_variant       Haploid
# 506   381707           other               other         other
# 508   392361         Diploid             Diploid       Diploid
# 515   419831         Diploid             Diploid       Diploid
# 516   425471         Diploid             Diploid       Diploid
# 520   434397         Diploid             Diploid       Diploid
#
#                 class                                    additional_muts  \
# 0             Diploid  TIP1-upstream_point_variant; YKR012C-upstream_...
# 1                 PKA  SEH1-missense_variant; ZIP1-missense_variant; ...
# 2        NotSequenced                                       NotSequenced
# 3                 PKA                                               None
# 4        NotSequenced                                       NotSequenced
# 8                 PKA                      RPL19A-upstream_point_variant
# 9        NotSequenced                                       NotSequenced
# 12       NotSequenced                                       NotSequenced
# 13       NotSequenced                                       NotSequenced
# 14            Diploid                                               None
# 15                PKA                        RIF1-upstream_indel_variant
# 16              other                                            nan-nan
# 18                PKA                                               None
# 19            Diploid                                               None
# 20   Adaptive Diploid                              ACF2-missense_variant
# 21                PKA  TAF9-upstream_point_variant; SHE3-missense_var...
# 22                PKA                              SEC5-missense_variant
# 23                PKA                              OSH2-missense_variant
# 24                PKA                              DUS1-missense_variant
# 26            Diploid                             CDC39-missense_variant
# 28       NotSequenced                                       NotSequenced
# 30            Diploid                                   DTR1-stop_gained
# 33   Adaptive Diploid                                               None
# 34            Diploid                                               None
# 35                PKA       PHR1-missense_variant; POP1-missense_variant
# 36       NotSequenced                                       NotSequenced
# 37            Diploid                                               None
# 38            Diploid  YIL161W-upstream_indel_variant; MAL31-missense...
# 39            Diploid  YPL205C-frameshift_variant; TPO2-missense_vari...
# 40            Diploid                   tL(CAA)G3-upstream_point_variant
# ..                ...                                                ...
# 445           Diploid                                               None
# 449           Diploid                                               None
# 453      NotSequenced                                       NotSequenced
# 454             other  TCB2-upstream_point_variant; SUP51,CYR1-upstre...
# 456           Diploid       FIG4-missense_variant; CNA1-missense_variant
# 457           Diploid                                               None
# 458             other  POP4-upstream_point_variant; FPK1-frameshift_v...
# 460           Diploid                                               None
# 461             other                                            nan-nan
# 463             other                                            nan-nan
# 470           Diploid                        MSK1-upstream_indel_variant
# 475             other  MTC5-upstream_point_variant; SNR6-non_coding_t...
# 476             other  PAU16-upstream_point_variant; BEM2-missense_va...
# 479               PKA                        VRG4-upstream_indel_variant
# 480           Diploid                                               None
# 483           Diploid                        FCF1-upstream_point_variant
# 485           Diploid                        RKM3-upstream_point_variant
# 486           Diploid                            IRC5-synonymous_variant
# 487             other                                            nan-nan
# 491               PKA  RET1-synonymous_variant; SUL1-upstream_point_v...
# 492           Diploid  YPL205C-frameshift_variant; APM2-upstream_inde...
# 493      NotSequenced                                       NotSequenced
# 496      NotSequenced                                       NotSequenced
# 503           Diploid                            DAD3-synonymous_variant
# 505               PKA  HCA4-synonymous_variant; YNL097W-A-missense_va...
# 506             other                                            nan-nan
# 508           Diploid                                               None
# 515           Diploid  IST1-upstream_point_variant; UBA3-missense_var...
# 516           Diploid  AST2-synonymous_variant; RDH54-upstream_point_...
# 520           Diploid                                               None
#
#      13.1_error  13.1_fitness  13.2_error  13.2_fitness        ...         \
# 0      0.086877      0.366047    0.083404      0.315150        ...
# 1      0.059241      1.628226    0.059251      1.570717        ...
# 2      0.069475      0.196277    0.068634      0.105044        ...
# 3      0.059303      1.133521    0.059304      1.206520        ...
# 4      0.059382      1.113742    0.059383      1.101149        ...
# 8      0.059639      1.351715    0.059628      1.287908        ...
# 9      0.079211      0.292709    0.078981      0.195564        ...
# 12     0.059238      1.474213    0.059241      1.421350        ...
# 13     0.059386      1.346518    0.059399      1.306377        ...
# 14     0.083986      0.379311    0.087251      0.141528        ...
# 15     0.060159      0.958329    0.060073      1.097166        ...
# 16     0.082998      0.154000    0.090883     -0.059056        ...
# 18     0.061904      0.894217    0.061555      0.914049        ...
# 19     0.076847      0.360570    0.076824      0.305632        ...
# 20     0.064041      0.764996    0.062675      0.721812        ...
# 21     0.060406      1.037151    0.060401      1.056155        ...
# 22     0.063501      0.916300    0.062726      0.865927        ...
# 23     0.068438      0.566557    0.066381      0.590361        ...
# 24     0.059451      1.068635    0.059437      1.107614        ...
# 26     0.069829      0.359467    0.067649      0.271368        ...
# 28     0.078641      0.292613    0.075804      0.347480        ...
# 30     0.070338      0.339854    0.068991      0.246891        ...
# 33     0.094035      0.309842    0.099074      0.214749        ...
# 34     0.073196      0.357392    0.071952      0.261251        ...
# 35     0.059427      1.053632    0.059419      1.062422        ...
# 36     0.059342      1.271395    0.059340      1.194536        ...
# 37     0.078640      0.224272    0.077516      0.106723        ...
# 38     0.079034      0.369947    0.079648      0.281938        ...
# 39     0.082043      0.348290    0.082691      0.182032        ...
# 40     0.065383      0.633945    0.064357      0.596045        ...
# ..          ...           ...         ...           ...        ...
# 445    0.076933      0.342377    0.075823      0.251000        ...
# 449    0.072606      0.282429    0.069992      0.280129        ...
# 453    0.074283      0.354089    0.073997      0.266467        ...
# 454    0.081108      0.247233    0.080181      0.270374        ...
# 456    0.091211      0.191445    0.086916      0.208347        ...
# 457    0.077942      0.289639    0.078630      0.177990        ...
# 458    0.073989      0.334930    0.071989      0.432699        ...
# 460    0.083120      0.321819    0.084441      0.187356        ...
# 461    0.083970     -0.004979    0.081767      0.006337        ...
# 463    0.118725     -0.042374    0.123026      0.025926        ...
# 470    0.089171      0.209058    0.089494      0.155851        ...
# 475    0.096424      0.028440    0.094621      0.121505        ...
# 476    0.088901      0.296852    0.086266      0.289191        ...
# 479    0.063722      0.669255    0.062303      0.653812        ...
# 480    0.073398      0.316490    0.070905      0.255303        ...
# 483    0.082500      0.332937    0.082534      0.241114        ...
# 485    0.074213      0.314297    0.071421      0.304927        ...
# 486    0.091259      0.343893    0.095533      0.153610        ...
# 487    0.090449      0.015507    0.090968      0.092012        ...
# 491    0.067461      0.534753    0.065551      0.516707        ...
# 492    0.080443      0.264483    0.078571      0.195807        ...
# 34             0.509985          0.021446            0.395201
# 35             0.497779          0.018231            0.402655
# 36             0.090457          0.031724           -0.514917
# 37             0.499260          0.031965            0.414712
# 38             0.496433          0.024186            0.399349
# 39             0.520722          0.023419            0.289491
# 40             0.758183          0.019494            0.404874
# ..                  ...               ...                 ...
# 445            0.494052          0.020938            0.372423
# 449            0.419995          0.023060            0.411700
# 453            0.534345          0.021048            0.354211
# 454            0.077296          0.045914            0.015877
# 456            0.564428          0.020534            0.383300
# 457            0.436073          0.021856            0.290055
# 458            0.339968          0.023833           -0.035937
# 460            0.544803          0.019972            0.392596
# 461            0.027403          0.037308           -0.032150
# 463           -0.237114          0.070758           -0.166050
# 470            0.505029          0.023335            0.257460
# 475           -0.000326          0.033421           -0.023933
# 476            0.262759          0.027413            0.026081
# 479            0.399447          0.027656            0.250601
# 480            0.504619          0.021446            0.373459
# 483            0.533147          0.019750            0.388993
# 485            0.472121          0.023477            0.423253
# 486            0.538842          0.021048            0.335317
# 487            0.021006          0.033337            0.010917
# 491            0.232760          0.029921            0.263086
# 492            0.535129          0.021984            0.300511
# 493            0.561421          0.020987            0.368624
# 496            0.546469          0.022492            0.403258
# 503            0.430622          0.042052            0.257859
# 505            0.364128          0.022195            0.341517
# 506            0.080974          0.028627            0.070118
# 508            0.507686          0.028244            0.270320
# 515            0.530906          0.023024            0.370425
# 516            0.552393          0.022665            0.391117
# 520            0.532587          0.022535            0.350332
#
#      1BB_SucRaf_error
# 0            0.065192
# 1            0.050561
# 2            0.067009
# 3            0.051965
# 4            0.055298
# 8            0.054950
# 9            0.069865
# 12           0.050919
# 13           0.051527
# 14           0.072595
# 15           0.051868
# 16           0.085009
# 18           0.055026
# 19           0.058922
# 20           0.089095
# 21           0.055785
# 22           0.054813
# 23           0.057701
# 24           0.054434
# 26           0.063089
# 28           0.067355
# 30           0.057150
# 33           0.075148
# 34           0.064220
# 35           0.051760
# 36           0.081091
# 37           0.091274
# 38           0.071425
# 39           0.070248
# 40           0.062321
# ..                ...
# 445          0.062663
# 449          0.067669
# 453          0.063548
# 454          0.094848
# 456          0.064032
# 457          0.065625
# 458          0.068568
# 460          0.061049
# 461          0.083013
# 463          0.125888
# 470          0.074442
# 475          0.076593
# 476          0.072363
# 479          0.064508
# 480          0.064233
# 483          0.059942
# 485          0.069398
# 486          0.065838
# 487          0.075421
# 491          0.069441
# 492          0.068976
# 493          0.064014
# 496          0.068000
# 503          0.115837
# 505          0.059128
# 506          0.068106
# 508          0.083514
# 515          0.070705
# 516          0.068880
# 520          0.068897
#
# [302 rows x 322 columns]

# %%
gene_type_combos = np.unique([(g,t) for g,t in zip(fitness_data['gene'].values,fitness_data['type'].values)],axis=0)

# %%
bc_list = []

for (g,t) in gene_type_combos:
    if not (('other' in g) or ('NotSequenced' in g)):
        this_gt = fitness_data[(fitness_data['gene'].isin([g]) & fitness_data['type'].isin([t]))]
        n_samples = int(np.floor(len(this_gt.index)/2))
        print(g,t,len(this_gt.index),n_samples)
        
        bc_list = bc_list + list(np.random.choice(this_gt['barcode'].values,n_samples))

exp_neutral =  fitness_data[fitness_data['class'].isin(['ExpNeutral'])]
n_samples = int(np.floor(len(exp_neutral.index)/2))
bc_list = bc_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 


fitness_data[fitness_data['barcode'].isin(bc_list)].to_csv('../data/mutant_train_set.csv',index=False)
## should this be balanced by mutation type (diploids dominate...)
# Out:
# CYR1 missense_variant 3 1
# Diploid Diploid 169 84
# Diploid + Chr11Amp Diploid + Chr11Amp 3 1
# Diploid + IRA1 missense_variant 1 0
# Diploid + IRA2 frameshift_variant 1 0
# Diploid + IRA2 missense_variant 1 0
# Diploid + IRA2 stop_gained 1 0
# GPB1 frameshift_variant 1 0
# GPB1 missense_variant 1 0
# GPB1 stop_gained 1 0
# GPB2 frameshift_variant 5 2
# GPB2 missense_variant 1 0
# GPB2 stop_gained 8 4
# IRA1 frameshift_variant 7 3
# IRA1 missense_variant 9 4
# IRA1 stop_gained 9 4
# IRA2 missense_variant 7 3
# KOG1 missense_variant 1 0
# PDE2 frameshift_variant 6 3
# PDE2 missense_variant 2 1
# PDE2 stop_gained 3 1
# RAS2 missense_variant 1 0
# SCH9 missense_variant 1 0
# TFS1 missense_variant 1 0
# TOR1 missense_variant 1 0

# %%
typical_test_list = []

number_per = 10

for (g,t) in gene_type_combos:
    if not (('other' in g) or ('NotSequenced' in g)):
        this_gt = fitness_data[(fitness_data['gene'].isin([g]) & fitness_data['type'].isin([t]))]
        n_samples = min([int(np.floor(len(this_gt.index))),number_per])
        print(g,t,len(this_gt.index),n_samples)
        
        typical_test_list = typical_test_list + list(np.random.choice(this_gt['barcode'].values,n_samples))

exp_neutral =  fitness_data[fitness_data['class'].isin(['ExpNeutral'])]
n_samples =  min([int(np.floor(len(this_gt.index))),number_per])
typical_test_list = typical_test_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 

typical_test_list = typical_test_list + list(fitness_data[fitness_data['gene']=='other']['barcode'].values) + list(fitness_data[fitness_data['gene']=='NotSequenced']['barcode'].values)

typical_test_list = [bc for bc in typical_test_list if bc not in bc_list]

fitness_data[fitness_data['barcode'].isin(typical_test_list)].to_csv('../data/mutant_test_set.csv',index=False)
# Out:
# CYR1 missense_variant 3 3
# Diploid Diploid 169 10
# Diploid + Chr11Amp Diploid + Chr11Amp 3 3
# Diploid + IRA1 missense_variant 1 1
# Diploid + IRA2 frameshift_variant 1 1
# Diploid + IRA2 missense_variant 1 1
# Diploid + IRA2 stop_gained 1 1
# GPB1 frameshift_variant 1 1
# GPB1 missense_variant 1 1
# GPB1 stop_gained 1 1
# GPB2 frameshift_variant 5 5
# GPB2 missense_variant 1 1
# GPB2 stop_gained 8 8
# IRA1 frameshift_variant 7 7
# IRA1 missense_variant 9 9
# IRA1 stop_gained 9 9
# IRA2 missense_variant 7 7
# KOG1 missense_variant 1 1
# PDE2 frameshift_variant 6 6
# PDE2 missense_variant 2 2
# PDE2 stop_gained 3 3
# RAS2 missense_variant 1 1
# SCH9 missense_variant 1 1
# TFS1 missense_variant 1 1
# TOR1 missense_variant 1 1

# %%
fitness_data[fitness_data['barcode'].isin(bc_list)].to_csv('../data/mutant_train_set.csv',index=False)

# %%
fitness_data[fitness_data['barcode'].isin(bc_list)]
# Out:
#      barcode                gene                type   ploidy  \
# 0         53             Diploid             Diploid  Diploid
# 8        689                IRA1  frameshift_variant  Haploid
# 15      1617                PDE2  frameshift_variant  Haploid
# 19      2037             Diploid             Diploid  Diploid
# 22      2468                IRA2    missense_variant  Haploid
# 26      2808             Diploid             Diploid  Diploid
# 30      3379             Diploid             Diploid  Diploid
# 37      3920             Diploid             Diploid  Diploid
# 40      4791             Diploid             Diploid  Diploid
# 41      4949                IRA1    missense_variant  Haploid
# 47      6271                PDE2         stop_gained  Haploid
# 48      6391  Diploid + Chr11Amp  Diploid + Chr11Amp  Diploid
# 54      7375             Diploid             Diploid  Diploid
# 61      7836                IRA1         stop_gained  Haploid
# 63      7961                IRA1    missense_variant  Haploid
# 64      7994                PDE2    missense_variant  Haploid
# 66      8297                CYR1    missense_variant  Haploid
# 71      9589             Diploid             Diploid  Diploid
# 73      9864                IRA1         stop_gained  Haploid
# 74      9888                GPB2  frameshift_variant  Haploid
# 82     10851                GPB2         stop_gained  Haploid
# 88     11667             Diploid             Diploid  Diploid
# 91     12090             Diploid             Diploid  Diploid
# 95     13029             Diploid             Diploid  Diploid
# 100    14160             Diploid             Diploid  Diploid
# 120    18420                IRA1  frameshift_variant  Haploid
# 122    18860             Diploid             Diploid  Diploid
# 123    18950             Diploid             Diploid  Diploid
# 127    19297             Diploid             Diploid  Diploid
# 129    19407                GPB2  frameshift_variant  Haploid
# ..       ...                 ...                 ...      ...
# 310    83967             Diploid             Diploid  Diploid
# 317    88706             Diploid             Diploid  Diploid
# 319    90003             Diploid             Diploid  Diploid
# 321    91807             Diploid             Diploid  Diploid
# 326    99035             Diploid             Diploid  Diploid
# 329   101051             Diploid             Diploid  Diploid
# 343   112239             Diploid             Diploid  Diploid
# 349   114628             Diploid             Diploid  Diploid
# 353   117631             Diploid             Diploid  Diploid
# 366   129569             Diploid             Diploid  Diploid
# 372   134904             Diploid             Diploid  Diploid
# 377   142859             Diploid             Diploid  Diploid
# 380   144535             Diploid             Diploid  Diploid
# 383   147119             Diploid             Diploid  Diploid
# 384   148821             Diploid             Diploid  Diploid
# 385   149824             Diploid             Diploid  Diploid
# 398   170554             Diploid             Diploid  Diploid
# 402   176764             Diploid             Diploid  Diploid
# 406   180905             Diploid             Diploid  Diploid
# 418   198950             Diploid             Diploid  Diploid
# 420   201777             Diploid             Diploid  Diploid
# 422   202468             Diploid             Diploid  Diploid
# 433   215325             Diploid             Diploid  Diploid
# 449   244443             Diploid             Diploid  Diploid
# 470   295458             Diploid             Diploid  Diploid
# 479   309655                PDE2  frameshift_variant  Haploid
# 480   310209             Diploid             Diploid  Diploid
# 483   317672             Diploid             Diploid  Diploid
# 492   338908             Diploid             Diploid  Diploid
# 505   379777                IRA2    missense_variant  Haploid
#
#                 class                                    additional_muts  \
# 0             Diploid  TIP1-upstream_point_variant; YKR012C-upstream_...
# 8                 PKA                      RPL19A-upstream_point_variant
# 15                PKA                        RIF1-upstream_indel_variant
# 19            Diploid                                               None
# 22                PKA                              SEC5-missense_variant
# 26            Diploid                             CDC39-missense_variant
# 30            Diploid                                   DTR1-stop_gained
# 37            Diploid                                               None
# 40            Diploid                   tL(CAA)G3-upstream_point_variant
# 41                PKA                                               None
# 47                PKA                                               None
# 48   Adaptive Diploid  SYH1-synonymous_variant; YDL144C-synonymous_va...
# 54            Diploid   HEL1-missense_variant; MSS116-synonymous_variant
# 61                PKA                              ABP1-missense_variant
# 63                PKA                            GRR1-synonymous_variant
# 64                PKA                              MYO5-missense_variant
# 66                PKA                                               None
# 71            Diploid                              HDA1-missense_variant
# 73                PKA                              HEL1-missense_variant
# 74                PKA                                               None
# 82                PKA  SIR4-upstream_point_variant; MIM1,tS-upstream_...
# 88            Diploid                              UFD4-missense_variant
# 91            Diploid                            MHP1-synonymous_variant
# 95            Diploid                                               None
# 100           Diploid  YNL234W-frameshift_variant; KIN1-synonymous_va...
# 120               PKA  FKS1-synonymous_variant; GEP4-upstream_indel_v...
# 122           Diploid                                               None
# 123           Diploid  TRT2,CBT1-upstream_indel_variant; PAU19-infram...
# 127           Diploid                                               None
# 129               PKA                tV,YKL068W-A-upstream_indel_variant
# ..                ...                                                ...
# 310           Diploid                                               None
# 317           Diploid  BRR2-missense_variant; GDE1-missense_variant; ...
# 319           Diploid                              SLX1-missense_variant
# 321           Diploid                                               None
# 326           Diploid                                               None
# 329           Diploid                                               None
# 343           Diploid                                               None
# 349           Diploid  tE(CUC)I-non_coding_transcript_exon_variant,no...
# 353           Diploid  IKI3-synonymous_variant; YNR063W-upstream_poin...
# 366           Diploid      RPS11B-intron_variant; FAR11-missense_variant
# 372           Diploid                     YEL067C-upstream_point_variant
# 377           Diploid                        ARR2-upstream_point_variant
# 380           Diploid                                               None
# 383           Diploid  BMT2-upstream_point_variant; SEC61-missense_va...
# 384           Diploid                                               None
# 385           Diploid                                               None
# 398           Diploid       FAT3-missense_variant; TUB2-missense_variant
# 402           Diploid                                   BRO1-stop_gained
# 406           Diploid                      RPS25B-upstream_point_variant
# 418           Diploid                              DSD1-missense_variant
# 420           Diploid  DOG1-upstream_point_variant; LOT5-upstream_poi...
# 422           Diploid                                               None
# 433           Diploid                                               None
# 449           Diploid                                               None
# 470           Diploid                        MSK1-upstream_indel_variant
# 479               PKA                        VRG4-upstream_indel_variant
# 480           Diploid                                               None
# 483           Diploid                        FCF1-upstream_point_variant
# 492           Diploid  YPL205C-frameshift_variant; APM2-upstream_inde...
# 505               PKA  HCA4-synonymous_variant; YNL097W-A-missense_va...
#
#      13.1_error  13.1_fitness  13.2_error  13.2_fitness        ...         \
# 0      0.086877      0.366047    0.083404      0.315150        ...
# 8      0.059639      1.351715    0.059628      1.287908        ...
# 15     0.060159      0.958329    0.060073      1.097166        ...
# 19     0.076847      0.360570    0.076824      0.305632        ...
# 22     0.063501      0.916300    0.062726      0.865927        ...
# 26     0.069829      0.359467    0.067649      0.271368        ...
# 30     0.070338      0.339854    0.068991      0.246891        ...
# 37     0.078640      0.224272    0.077516      0.106723        ...
# 380            0.524106          0.018871            0.355927
# 383            0.495336          0.023966            0.321817
# 384            0.722694          0.021477            0.423178
# 385            0.561952          0.019527            0.364149
# 398            0.491499          0.022419            0.408238
# 402            0.488763          0.023534            0.356771
# 406            0.465915          0.025201            0.398564
# 418            0.526497          0.021063            0.411058
# 420            0.510411          0.022456            0.387403
# 422            0.505192          0.024323            0.362939
# 433            0.502124          0.021699            0.376679
# 449            0.419995          0.023060            0.411700
# 470            0.505029          0.023335            0.257460
# 479            0.399447          0.027656            0.250601
# 480            0.504619          0.021446            0.373459
# 483            0.533147          0.019750            0.388993
# 492            0.535129          0.021984            0.300511
# 505            0.364128          0.022195            0.341517
#
#      1BB_SucRaf_error
# 0            0.065192
# 8            0.054950
# 15           0.051868
# 19           0.058922
# 22           0.054813
# 26           0.063089
# 30           0.057150
# 37           0.091274
# 40           0.062321
# 41           0.052532
# 47           0.053661
# 48           0.091561
# 54           0.067145
# 61           0.051708
# 63           0.051491
# 64           0.053013
# 66           0.058427
# 71           0.061022
# 73           0.052467
# 74           0.053682
# 82           0.057415
# 88           0.065064
# 91           0.073330
# 95           0.065551
# 100          0.073108
# 120          0.052508
# 122          0.066739
# 123          0.062092
# 127          0.058830
# 129          0.054633
# ..                ...
# 310          0.064150
# 317          0.067825
# 319          0.060950
# 321          0.063161
# 326          0.062476
# 329          0.075232
# 343          0.065227
# 349          0.069269
# 353          0.057565
# 366          0.093257
# 372          0.068228
# 377          0.070484
# 380          0.057492
# 383          0.073615
# 384          0.070886
# 385          0.059831
# 398          0.066768
# 402          0.069020
# 406          0.073389
# 418          0.063627
# 420          0.067633
# 422          0.071831
# 433          0.065162
# 449          0.067669
# 470          0.074442
# 479          0.064508
# 480          0.064233
# 483          0.059942
# 492          0.068976
# 505          0.059128
#
# [91 rows x 322 columns]

# %%
exp_neutral
# Out:
#      barcode          gene          type        ploidy       class  \
# 292    72939  NotSequenced  NotSequenced  NotSequenced  ExpNeutral
#
#     additional_muts  13.1_error  13.1_fitness  13.2_error  13.2_fitness  \
# 292    NotSequenced    0.094346      0.035435    0.095718      0.020351
#
#            ...         1BB_1%Raf_fitness  1BB_1%Raf_error  \
# 292        ...                    0.0268         0.054952
#
#      1BB_0.5%Raf_fitness  1BB_0.5%Raf_error  1BB_1%Gly_fitness  \
# 292             0.003748           0.031132          -0.021662
#
#      1BB_1%Gly_error  1BB_1%EtOH_fitness  1BB_1%EtOH_error  \
# 292          0.04797            0.042239          0.040955
#
#      1BB_SucRaf_fitness  1BB_SucRaf_error
# 292            0.006673          0.086473
#
# [1 rows x 322 columns]

# %%
minimal_bc_list = []

number_per = 2

for (g,t) in gene_type_combos:
    if not (('other' in g) or ('NotSequenced' in g)):
        this_gt = fitness_data[(fitness_data['gene'].isin([g]) & fitness_data['type'].isin([t]))]
        n_samples = min([int(np.floor(len(this_gt.index)/2)),number_per])
        print(g,t,len(this_gt.index),n_samples)
        
        minimal_bc_list = minimal_bc_list + list(np.random.choice(this_gt['barcode'].values,n_samples))

exp_neutral =  fitness_data[fitness_data['class'].isin(['ExpNeutral'])]
n_samples = int(np.floor(len(exp_neutral.index)/2))
minimal_bc_list = minimal_bc_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples))  
## should this be balanced by mutation type (diploids dominate...)
# Out:
# CYR1 missense_variant 3 1
# Diploid Diploid 169 2
# Diploid + Chr11Amp Diploid + Chr11Amp 3 1
# Diploid + IRA1 missense_variant 1 0
# Diploid + IRA2 frameshift_variant 1 0
# Diploid + IRA2 missense_variant 1 0
# Diploid + IRA2 stop_gained 1 0
# GPB1 frameshift_variant 1 0
# GPB1 missense_variant 1 0
# GPB1 stop_gained 1 0
# GPB2 frameshift_variant 5 2
# GPB2 missense_variant 1 0
# GPB2 stop_gained 8 2
# IRA1 frameshift_variant 7 2
# IRA1 missense_variant 9 2
# IRA1 stop_gained 9 2
# IRA2 missense_variant 7 2
# KOG1 missense_variant 1 0
# PDE2 frameshift_variant 6 2
# PDE2 missense_variant 2 1
# PDE2 stop_gained 3 1
# RAS2 missense_variant 1 0
# SCH9 missense_variant 1 0
# TFS1 missense_variant 1 0
# TOR1 missense_variant 1 0

# %%
fitness_data[fitness_data['barcode'].isin(minimal_bc_list)].to_csv('../data/mutant_minimal_train_set.csv',index=False)

# %%
minimal_test_list = []

number_per = 10

for (g,t) in gene_type_combos:
    if not (('other' in g) or ('NotSequenced' in g)):
        this_gt = fitness_data[(fitness_data['gene'].isin([g]) & fitness_data['type'].isin([t]))]
        n_samples = min([int(np.floor(len(this_gt.index))),number_per])
        print(g,t,len(this_gt.index),n_samples)
        
        minimal_test_list = minimal_test_list + list(np.random.choice(this_gt['barcode'].values,n_samples))

exp_neutral =  fitness_data[fitness_data['class'].isin(['ExpNeutral'])]
n_samples =  min([int(np.floor(len(this_gt.index))),number_per])
minimal_test_list = minimal_test_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 

minimal_test_list = minimal_test_list + list(fitness_data[fitness_data['gene']=='other']['barcode'].values) + list(fitness_data[fitness_data['gene']=='NotSequenced']['barcode'].values)

minimal_test_list = [bc for bc in minimal_test_list if bc not in minimal_bc_list]

fitness_data[fitness_data['barcode'].isin(minimal_test_list)].to_csv('../data/mutant_minimal_test_set.csv',index=False)
# Out:
# CYR1 missense_variant 3 3
# Diploid Diploid 169 10
# Diploid + Chr11Amp Diploid + Chr11Amp 3 3
# Diploid + IRA1 missense_variant 1 1
# Diploid + IRA2 frameshift_variant 1 1
# Diploid + IRA2 missense_variant 1 1
# Diploid + IRA2 stop_gained 1 1
# GPB1 frameshift_variant 1 1
# GPB1 missense_variant 1 1
# GPB1 stop_gained 1 1
# GPB2 frameshift_variant 5 5
# GPB2 missense_variant 1 1
# GPB2 stop_gained 8 8
# IRA1 frameshift_variant 7 7
# IRA1 missense_variant 9 9
# IRA1 stop_gained 9 9
# IRA2 missense_variant 7 7
# KOG1 missense_variant 1 1
# PDE2 frameshift_variant 6 6
# PDE2 missense_variant 2 2
# PDE2 stop_gained 3 3
# RAS2 missense_variant 1 1
# SCH9 missense_variant 1 1
# TFS1 missense_variant 1 1
# TOR1 missense_variant 1 1
