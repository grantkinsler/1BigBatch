# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.spatial import distance
from scipy.stats.mstats import gmean
# %matplotlib inline
from itertools import combinations
from itertools import chain
import sys
import os
import copy
sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()

fgm_simulation_path = '/Users/grantkinsler/Documents/Stanford/Research/StarryNight/Git/starry-night/Simulations/FGM_simulation_callable.py'
# sys.path.append(os.path.dirname(os.path.expanduser(fgm_simulation_path)))
# from FGM_simulation_callable import simulation, nball_pull, gaussian_fitness

tools_path = '../code/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(953527608) # for exact figure reproducibility use this seed

# %%
# fitness_data = p.read_csv('../data/DoubleBC_Merged_Fitness_Atish_Default_AllConditions.csv')
# fitness_data = p.read_csv('../data/DoubleBC_Merged_Fitness_Atish_Weighted_Default_AllConditions_IncludingOld_swapsremoved.csv')
fitness_data = p.read_csv('../data/fitness_weighted_allconditions_swapsremoved_neutral2xpass.csv')

# %%
fitness_data = fitness_data.replace([np.inf, -np.inf], np.nan).dropna()
# this_data = merged_fitness_data
# this_data = this_data.replace([np.inf, -np.inf], np.nan)
# # this_data = this_data.dropna('columns',how='all')
# this_data = this_data.dropna()

# %%
mutation_types =  np.unique(fitness_data['mutation_type'])

# %% [markdown]
# We can construct a training and test set of mutants by, for each mutant type (combination of gene and mutation type), dividing half of those mutant types into each set. "Half" is calculated by rounding down to be conservative, so mutant types with only one representative are only present in the "test" set.
#
# Because "other" (mutation not in RAS/PKA or TOR pathway and/or Diploid) and "Not Sequenced" mutants have genotypes that are not easily classified as being similar to something else (or unknown), they are not included in these training and test sets.
#
# Because neutral lineages should (in theory) give no information on the space, they are included only in the test set.

# %%
bc_list = []

for mut_type in mutation_types:
    if not (('other' in mut_type) or ('NotSequenced' in mut_type) or ('ExpNeutral' in mut_type)):
        this_mut_type = fitness_data[(fitness_data['mutation_type'].isin([mut_type]))]
        n_samples = int(np.floor(len(this_mut_type.index)/2))
        print(mut_type,len(this_mut_type.index),n_samples)
        
        bc_list = bc_list + list(np.random.choice(this_mut_type['barcode'].values,n_samples))

# exp_neutral =  fitness_data[fitness_data['class'].isin(['ExpNeutral'])]
# n_samples = int(np.floor(len(exp_neutral.index)/2))
# bc_list = bc_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 


fitness_data[fitness_data['barcode'].isin(bc_list)].to_csv('../data/mutant_train_set_neutral2xpass.csv',index=False)

typical_test_list = []

number_per = 10

for mut_type in mutation_types:
    if not (('other' in mut_type) or ('NotSequenced' in mut_type)):
        this_mut_type = fitness_data[(fitness_data['mutation_type'].isin([mut_type]))]
        n_samples = min([int(np.floor(len(this_mut_type.index))),number_per])
        print(mut_type,len(this_mut_type.index),n_samples)
        
        options = [bc for bc in this_mut_type['barcode'].values if bc not in bc_list]
        n_samples = min([len(options),n_samples])
        
        typical_test_list = typical_test_list + list(np.random.choice(options,n_samples,replace=False))

exp_neutral =  fitness_data[fitness_data['mutation_type'].isin(['ExpNeutral'])]
n_samples =  min([int(np.floor(len(this_mut_type.index))),number_per])
# typical_test_list = typical_test_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 
typical_test_list = typical_test_list + list(exp_neutral['barcode'].values) 

typical_test_list = typical_test_list + list(fitness_data[fitness_data['gene']=='other']['barcode'].values) + list(fitness_data[fitness_data['gene']=='NotSequenced']['barcode'].values)

typical_test_list = [bc for bc in typical_test_list if bc not in bc_list]

fitness_data[fitness_data['barcode'].isin(typical_test_list)].to_csv('../data/mutant_test_set_neutral2xpass.csv',index=False)
# Out:
# CYR1 3 1
# Diploid 188 94
# Diploid + Chr11Amp 3 1
# Diploid + Chr12Amp 1 0
# Diploid + IRA1 1 0
# Diploid + IRA2 3 1
# Diploid_adaptive 11 5
# GPB1 4 2
# GPB2 14 7
# IRA1_missense 9 4
# IRA1_nonsense 20 10
# IRA2 8 4
# KOG1 1 0
# PDE2 11 5
# RAS2 1 0
# SCH9 1 0
# TFS1 1 0
# TOR1 1 0
# CYR1 3 3
# Diploid 188 10
# Diploid + Chr11Amp 3 3
# Diploid + Chr12Amp 1 1
# Diploid + IRA1 1 1
# Diploid + IRA2 3 3
# Diploid_adaptive 11 10
# ExpNeutral 3 3
# GPB1 4 4
# GPB2 14 10
# IRA1_missense 9 9
# IRA1_nonsense 20 10
# IRA2 8 8
# KOG1 1 1
# PDE2 11 10
# RAS2 1 1
# SCH9 1 1
# TFS1 1 1
# TOR1 1 1

# %% [markdown]
#  The "minimal" set below tries to account for imbalances in the number of mutants per type by instead taking 2 of every mutant type in the training set and (at most) 10 of each for the testing set.
#
# Again, "other" mutants and "Not Sequenced" are excluded.

# %%
minimal_bc_list = []

number_per = 4
print('MINIMAL TRAINING SET')
for mut_type in mutation_types:
    if not (('other' in mut_type) or ('NotSequenced' in mut_type) or ('ExpNeutral' in mut_type)):
        this_mut_type = fitness_data[(fitness_data['mutation_type'].isin([mut_type]))]
        n_samples =  min([int(np.floor(len(this_mut_type.index)/2)),number_per])
        print(mut_type,len(this_mut_type.index),n_samples)
        
        minimal_bc_list = sorted(np.unique(minimal_bc_list + list(np.random.choice(this_mut_type['barcode'].values,n_samples,replace=False))))

fitness_data[fitness_data['barcode'].isin(minimal_bc_list)].to_csv('../data/mutant_minimal_train_set_neutral2xpass.csv',index=False)

minimal_test_list = []

number_per = 10
print('MINIMAL TESTING SET')
for mut_type in mutation_types:
    if not (('other' in mut_type) or ('NotSequenced' in mut_type)):
        this_mut_type = fitness_data[(fitness_data['mutation_type'].isin([mut_type]))]
        options = [bc for bc in this_mut_type['barcode'].values if bc not in minimal_bc_list]
        n_samples = min([int(np.floor(len(options))),number_per])
#         print(options)
        print(mut_type,len(options),n_samples)
        
        minimal_test_list = sorted(np.unique(minimal_test_list + list(np.random.choice(options,n_samples,replace=False))))

exp_neutral =  fitness_data[fitness_data['mutation_type'].isin(['ExpNeutral'])]
# n_samples =  min([int(np.floor(len(this_mut_type.index))),number_per])
# minimal_test_list = minimal_test_list + list(np.random.choice(exp_neutral['barcode'].values,n_samples)) 
minimal_test_list = sorted(np.unique(minimal_test_list + [bc for bc in list(exp_neutral['barcode'].values) if bc not in minimal_test_list]))


# print(list(np.random.choice(exp_neutral['barcode'].values,n_samples)) )
# minimal_test_list = minimal_test_list + list(fitness_data[fitness_data['gene']=='other']['barcode'].values) + list(fitness_data[fitness_data['gene']=='NotSequenced']['barcode'].values)

minimal_test_list = [bc for bc in minimal_test_list if bc not in minimal_bc_list]

fitness_data[fitness_data['barcode'].isin(minimal_test_list)].to_csv('../data/mutant_minimal_test_set_neutral2xpass.csv',index=False)
# Out:
# MINIMAL TRAINING SET
# CYR1 3 1
# Diploid 188 4
# Diploid + Chr11Amp 3 1
# Diploid + Chr12Amp 1 0
# Diploid + IRA1 1 0
# Diploid + IRA2 3 1
# Diploid_adaptive 11 4
# GPB1 4 2
# GPB2 14 4
# IRA1_missense 9 4
# IRA1_nonsense 20 4
# IRA2 8 4
# KOG1 1 0
# PDE2 11 4
# RAS2 1 0
# SCH9 1 0
# TFS1 1 0
# TOR1 1 0
# MINIMAL TESTING SET
# CYR1 2 2
# Diploid 184 10
# Diploid + Chr11Amp 2 2
# Diploid + Chr12Amp 1 1
# Diploid + IRA1 1 1
# Diploid + IRA2 2 2
# Diploid_adaptive 7 7
# ExpNeutral 3 3
# GPB1 2 2
# GPB2 10 10
# IRA1_missense 5 5
# IRA1_nonsense 16 10
# IRA2 4 4
# KOG1 1 1
# PDE2 7 7
# RAS2 1 1
# SCH9 1 1
# TFS1 1 1
# TOR1 1 1

# %% [markdown]
# To account for the fact "other" mutants may in fact have interesting phenotypic behavior that isn't capture by the commonly hit mutants, we also include another training set where we divide these equally into the training and test set, but otherwise keep the "minimal" training and test sets from above.
#
# Note that though the "other" mutants have no obvious commonalities in genotype, it is possible there is over-representation of particular mutants in some of these sets.
#
# To avoid the problem that some of the "Not Sequenced" mutants are actually likely to contain some similarities, particularly because we've not sequenced some because of similarities to others (i.e. likely to be Diploid/IRA1) and this may put our sets out of balance.

# %%
# this_gt = fitness_data[(fitness_data['gene'].isin(['other']))]
this_mut = fitness_data[(fitness_data['mutation_type'].isin(['other_adaptive']))]
n_samples = int(len(this_mut.index)/2)
print(n_samples,len(this_mut.index))
train_others = list(np.random.choice(this_mut['barcode'].values,n_samples))
test_others = [bc for bc in this_mut['barcode'].values if bc not in train_others]
        
training_w_others = minimal_bc_list + train_others
fitness_data[fitness_data['barcode'].isin(training_w_others)].to_csv('../data/mutant_minimal+otheradaptive_train_set_neutral2xpass.csv',index=False)
print(len(training_w_others))

testing_w_others = minimal_test_list + test_others
fitness_data[fitness_data['barcode'].isin(testing_w_others)].to_csv('../data/mutant_minimal+otheradaptive_test_set_neutral2xpass.csv',index=False)
print(len(testing_w_others))

fitness_data[fitness_data['barcode'].isin(train_others)].to_csv('../data/mutant_justotheradaptive_train_set_neutral2xpass.csv',index=False)

fitness_data[fitness_data['barcode'].isin(test_others)].to_csv('../data/mutant_justotheradaptive_test_set_neutral2xpass.csv',index=False)
# Out:
# 3 7
# 36
# 75

# %%
print(len(fitness_data['barcode'].values))
# Out:
# 421

# %%
len(minimal_bc_list),len(minimal_test_list),len(training_w_others),len(testing_w_others),len(train_others),len(test_others)
# Out:
# (33, 71, 37, 76, 4, 5)

# %%
fitness_data[(fitness_data['mutation_type'].isin(['other']))]
# Out:
#      barcode   gene   type ploidy  class  \
# 16      1641  other  other  other  other
# 17      1683  other  other  other  other
# 53      7291  other  other  other  other
# 68      8825  other  other  other  other
# 77     10307  other  other  other  other
# 97     13183  other  other  other  other
# 113    17499  other  other  other  other
# 133    19894  other  other  other  other
# 138    20632  other  other  other  other
# 160    24151  other  other  other  other
# 169    26612  other  other  other  other
# 179    29375  other  other  other  other
# 195    34189  other  other  other  other
# 202    39066  other  other  other  other
# 204    39633  other  other  other  other
# 210    41601  other  other  other  other
# 223    45512  other  other  other  other
# 232    49174  other  other  other  other
# 242    53054  other  other  other  other
# 244    54461  other  other  other  other
# 252    58107  other  other  other  other
# 258    60333  other  other  other  other
# 259    60549  other  other  other  other
# 270    64731  other  other  other  other
# 280    70033  other  other  other  other
# 281    70408  other  other  other  other
# 289    72008  other  other  other  other
# 290    72395  other  other  other  other
# 296    74280  other  other  other  other
# 301    77609  other  other  other  other
# ..       ...    ...    ...    ...    ...
# 359   121650  other  other  other  other
# 363   122302  other  other  other  other
# 368   132805  other  other  other  other
# 375   142054  other  other  other  other
# 379   143344  other  other  other  other
# 397   164627  other  other  other  other
# 400   171083  other  other  other  other
# 415   195473  other  other  other  other
# 416   195887  other  other  other  other
# 423   205157  other  other  other  other
# 427   208465  other  other  other  other
# 441   230962  other  other  other  other
# 446   238413  other  other  other  other
# 448   241857  other  other  other  other
# 451   247616  other  other  other  other
# 461   270104  other  other  other  other
# 463   276407  other  other  other  other
# 464   277185  other  other  other  other
# 467   287352  other  other  other  other
# 468   294706  other  other  other  other
# 475   303501  other  other  other  other
# 481   316048  other  other  other  other
# 487   330943  other  other  other  other
# 490   334616  other  other  other  other
# 498   352078  other  other  other  other
# 499   352705  other  other  other  other
# 506   381707  other  other  other  other
# 514   419648  other  other  other  other
# 518   430247  other  other  other  other
# 522   454851  other  other  other  other
#
#                                        additional_muts  1.4%-R1_error  \
# 16                                             nan-nan       0.104534
# 17   SDH3-upstream_point_variant; MFM1-missense_var...       0.118186
# 53   IMP4-missense_variant; YER156C,COG3-upstream_i...       0.125247
# 68                        ATG32-upstream_indel_variant       0.104268
# 77                                             nan-nan       0.091558
# 97                                             nan-nan       0.042835
# 113  LCP5-upstream_indel_variant; PTC3-synonymous_v...       0.173937
# 133                    tQ(UUG)C-upstream_indel_variant       0.115310
# 138               YAR023C,SUP56-upstream_indel_variant       0.112300
# 160                                            nan-nan       0.269317
# 169                            UBI4-frameshift_variant       0.124361
# 179                                            nan-nan       0.082241
# 195                                            nan-nan       0.097563
# 202                           RAD30-synonymous_variant       0.105340
# 204  RPO41-synonymous_variant; tA,-upstream_indel_v...       0.147539
# 210                             ATG23-missense_variant       0.171594
# 223                            SCO2-synonymous_variant       0.173898
# 232                                            nan-nan       0.132559
# 242                       ATG17-upstream_point_variant       0.155138
# 244  YAP1802-upstream_point_variant; FIR1-missense_...       0.107548
# 252                                            nan-nan       0.110732
# 258  tQ,-upstream_indel_variant; YMR295C-upstream_p...       0.139158
# 259                                            nan-nan       0.096328
# 270  SEN1-missense_variant; tV,YKL068W-A-upstream_i...       0.084115
# 280  RPR1-non_coding_transcript_exon_variant,non_co...       0.097717
# 281  VRG4-upstream_indel_variant; FIT1-frameshift_v...       0.142082
# 289     MIG3-frameshift_variant; SEC8-missense_variant       0.210178
# 290                       HSP42-upstream_point_variant       0.109692
# 296  YRO2-upstream_point_variant; MZM1-missense_var...       0.119003
# 301  FUN12-missense_variant; RPL11B-upstream_indel_...       0.150703
# ..                                                 ...            ...
# 359  FKS1-missense_variant; YPL257W-upstream_point_...       0.204239
# 363                           YIL169C-missense_variant       0.139147
# 368                            PES4-frameshift_variant       0.102206
# 375                        SUP7-upstream_indel_variant       0.089330
# 379                            SSB2-synonymous_variant       0.289165
# 397  YEF3-missense_variant; YGR053C-upstream_point_...       0.118654
# 400  CYC3-upstream_point_variant; PST2-upstream_poi...       0.086079
# 415  RML2-upstream_point_variant; VRG4-upstream_ind...       0.122544
# 416  RTT102-missense_variant; PBP1-missense_variant...       0.182790
# 423                                            nan-nan       0.161764
# 427                              CHS3-missense_variant       0.100832
# 441                                            nan-nan       0.124347
# 446                                            nan-nan       0.117418
# 448                       YLL066W-B-frameshift_variant       0.136934
# 451                       FYV10-upstream_indel_variant       0.115857
# 461                                            nan-nan       0.100861
# 463                                            nan-nan       0.145840
# 464                        MSK1-upstream_indel_variant       0.126530
# 467                                            nan-nan       0.128328
# 468                              ADP1-missense_variant       0.145335
# 475  MTC5-upstream_point_variant; SNR6-non_coding_t...       0.104621
# 481  PET127-upstream_point_variant; SUP61-upstream_...       0.092468
# 487                                            nan-nan       0.107699
# 490                            FAR3-frameshift_variant       0.131606
# 498                     YEL023C-upstream_point_variant       0.243355
# 499                                            nan-nan       0.462316
# 506                                            nan-nan       0.092611
# 514                                            nan-nan       0.153768
# 518                                            nan-nan       0.198839
# 522  CDC11-upstream_indel_variant; PCA1-synonymous_...       0.109228
#
#      1.4%-R1_fitness  1.4%-R2_error  1.4%-R2_fitness      ...        \
# 16         -0.243305       0.219505        -0.022012      ...
# 17         -0.075047       0.329653        -0.073542      ...
# 53          0.315658       0.276059        -0.087561      ...
# 68          0.437782       0.299720        -0.081207      ...
# 77          0.104966       0.170830         0.188714      ...
# 97          0.907085       0.074215         0.968915      ...
# 289           -0.023109          0.116726          other
# 290            0.085610          0.068697          other
# 296            0.028598          0.098033          other
# 301            0.065893          0.080246          other
# ..                  ...               ...            ...
# 359            0.058175          0.093016          other
# 363            0.121861          0.072235          other
# 368            0.068607          0.075629          other
# 375           -0.052269          0.085453          other
# 379            0.166109          0.154566          other
# 397            0.066445          0.078434          other
# 400           -0.028948          0.070686          other
# 415           -0.018560          0.083217          other
# 416           -0.029564          0.087718          other
# 423            0.102875          0.080850          other
# 427            0.009022          0.077200          other
# 441            0.002199          0.071496          other
# 446           -0.017279          0.087435          other
# 448            0.043334          0.072310          other
# 451           -0.053209          0.084574          other
# 461           -0.032150          0.083013          other
# 463           -0.166050          0.125888          other
# 464           -0.082436          0.096105          other
# 467            0.132794          0.082043          other
# 468            0.094100          0.082718          other
# 475           -0.023933          0.076593          other
# 481            0.031544          0.074953          other
# 487            0.010917          0.075421          other
# 490           -0.183180          0.094796          other
# 498            0.036961          0.090184          other
# 499           -0.019862          0.079093          other
# 506            0.070118          0.068106          other
# 514            0.041091          0.094317          other
# 518           -0.168142          0.106724          other
# 522            0.067383          0.084576          other
#
# [71 rows x 369 columns]

# %%
fitness_data[(fitness_data['mutation_type'].isin(['Diploid_adaptive']))]

# %%
fitness_data[(fitness_data['mutation_type'].isin(['NotSequenced_adaptive']))]
# Out:
#      barcode          gene          type        ploidy         class  \
# 2        262  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 4        323  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 9        697  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 12      1379  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 13      1488  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 28      3250  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 36      3730  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 43      5654  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 52      7269  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 70      9518  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 102    14485  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 121    18501  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 128    19379  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 149    22162  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 151    22372  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 153    22669  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 180    29473  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 188    32201  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 200    38775  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 218    44777  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 220    44966  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 221    44971  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 225    46200  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 230    48822  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 231    48904  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 237    50880  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 243    53230  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 255    59345  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 279    69928  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 302    77824  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 308    83255  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 323    94393  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 327   100501  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 338   107859  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 364   124210  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 365   128188  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 371   134867  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 381   144969  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 408   187133  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 413   193269  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 421   201919  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 432   215309  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 450   246829  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 453   251379  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 466   283952  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 472   296771  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 493   340123  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 496   349198  NotSequenced  NotSequenced  NotSequenced  NotSequenced
# 497   349927  NotSequenced  NotSequenced  NotSequenced  NotSequenced
#
#     additional_muts  1.4%-R1_error  1.4%-R1_fitness  1.4%-R2_error  \
# 2      NotSequenced       0.048088         0.362946       0.095466
# 4      NotSequenced       0.037480         1.011827       0.042560
# 9      NotSequenced       0.056581         0.446857       0.121933
# 12     NotSequenced       0.036929         1.197959       0.038409
# 13     NotSequenced       0.037882         0.914444       0.045158
# 28     NotSequenced       0.052595         0.545628       0.099959
# 36     NotSequenced       0.037535         0.937621       0.046086
# 43     NotSequenced       0.054587         0.463124       0.108610
# 52     NotSequenced       0.041768         0.719641       0.066021
# 70     NotSequenced       0.068526         0.569159       0.150248
# 102    NotSequenced       0.038336         0.842731       0.048654
# 121    NotSequenced       0.062875         0.465538       0.135946
# 128    NotSequenced       0.091353         0.617804       0.227045
# 149    NotSequenced       0.058615         0.441273       0.132731
# 151    NotSequenced       0.153941         0.258533       0.260516
# 153    NotSequenced       0.082307         0.488591       0.184528
# 180    NotSequenced       0.038393         0.890720       0.049362
# 188    NotSequenced       0.072697         0.578106       0.166293
# 200    NotSequenced       0.058656         0.395175       0.119485
# 218    NotSequenced       0.123485         0.351042       0.365499
# 220    NotSequenced       0.074844         0.546788       0.167816
# 221    NotSequenced       0.054940         0.364582       0.106296
# 225    NotSequenced       0.166537         0.564653       0.331184
# 230    NotSequenced       0.084616         0.015081       0.184754
# 231    NotSequenced       0.062815         0.345645       0.125804
# 237    NotSequenced       0.049069         0.471945       0.088092
# 243    NotSequenced       0.098869         0.375944       0.241887
# 255    NotSequenced       0.046417         0.441539       0.079285
# 279    NotSequenced       0.048352         0.395737       0.083760
# 302    NotSequenced       0.066991         0.542065       0.168219
# 308    NotSequenced       0.048472         0.361787       0.080814
# 323    NotSequenced       0.115445         0.497370       0.400182
# 327    NotSequenced       0.055413         0.490163       0.107703
# 338    NotSequenced       0.106573         0.282713       0.247643
# 364    NotSequenced       0.056131         0.346214       0.116915
# 365    NotSequenced       0.052376         0.436480       0.097099
# 371    NotSequenced       0.061413         0.296792       0.129254
# 381    NotSequenced       0.075877         0.346107       0.144093
# 408    NotSequenced       0.122900         0.809022       0.345383
# 413    NotSequenced       0.055251         0.348787       0.112550
# 421    NotSequenced       0.053332         0.352011       0.110577
# 432    NotSequenced       0.054525         0.394644       0.104277
# 450    NotSequenced       0.134182         1.006273       0.393281
# 453    NotSequenced       0.046282         0.442032       0.079687
# 466    NotSequenced       0.126408         0.344853       0.266193
# 472    NotSequenced       0.086414         0.579088       0.226431
# 493    NotSequenced       0.053567         0.428175       0.107272
# 496    NotSequenced       0.051962         0.503970       0.099149
# 497    NotSequenced       0.076362         0.238927       0.149943
#
#      1.4%-R2_fitness          ...            1BB_1%Raf_error  \
# 2           0.263130          ...                   0.052701
# 4           0.947841          ...                   0.043157
# 9           0.535259          ...                   0.050038
# 12          1.259083          ...                   0.042748
# 13          1.020749          ...                   0.042775
# 28          0.454508          ...                   0.049603
# 36          0.769274          ...                   0.043168
# 43          0.424426          ...                   0.048633
# 52          0.677798          ...                   0.043162
# 70          0.428477          ...                   0.058720
# 102         0.759455          ...                   0.044109
# 121         0.506007          ...                   0.051547
# 128         0.332433          ...                   0.048510
# 149         0.427685          ...                   0.046518
# 151         0.592310          ...                   0.053057
# 153         0.678572          ...                   0.061181
# 180         0.977649          ...                   0.042771
# 188         0.425123          ...                   0.050766
# 200         0.412288          ...                   0.050786
# 218         0.470563          ...                   0.046844
# 220         0.597208          ...                   0.058039
# 221         0.478345          ...                   0.049874
# 225         0.347370          ...                   0.047110
# 230         0.225939          ...                   0.045347
# 231         0.388306          ...                   0.055659
# 237         0.488236          ...                   0.048694
# 243         0.340959          ...                   0.049492
# 255         0.475355          ...                   0.047829
# 279         0.481521          ...                   0.050045
# 302         0.245377          ...                   0.051880
# 43          0.029490            0.506449          0.021643
# 52          0.024257            0.385693          0.019534
# 70          0.037298            0.477029          0.028644
# 102         0.025205            0.523362          0.019173
# 121         0.032730            0.531277          0.023683
# 128         0.028923            0.522009          0.021598
# 149         0.033630            0.251886          0.032333
# 151         0.033373            0.490200          0.025001
# 153         0.039052            0.280001          0.032840
# 180         0.023698            0.404895          0.020196
# 188         0.031776            0.531235          0.023280
# 200         0.030396            0.425933          0.023232
# 218         0.028134            0.547664          0.020698
# 220         0.036094            0.515193          0.026982
# 221         0.029523            0.537436          0.021842
# 225         0.027920            0.504062          0.020573
# 230         0.027919            0.495172          0.022228
# 231         0.036732            0.402514          0.029133
# 237         0.029948            0.509789          0.022044
# 243         0.029584            0.504149          0.021890
# 255         0.029294            0.531995          0.021576
# 279         0.029902            0.513589          0.022515
# 302         0.035977            0.444038          0.028721
# 308         0.028133            0.472209          0.020928
# 323         0.031596            0.507829          0.023713
# 327         0.031612            0.466818          0.024010
# 338         0.028806            0.525445          0.020936
# 364         0.028143            0.498803          0.020742
# 365         0.034588            0.505370          0.025778
# 371         0.037620            0.258534          0.030933
# 381         0.040896            0.240248          0.034883
# 408         0.062749            0.496645          0.072770
# 413         0.041004            0.332830          0.034075
# 421         0.028331            0.443504          0.021498
# 432         0.034283            0.320817          0.026901
# 450         0.058842            0.469644          0.076470
# 453         0.029027            0.535088          0.021251
# 466         0.049923            0.508267          0.038190
# 472         0.028174            0.566726          0.020462
# 493         0.029159            0.562512          0.021189
# 496         0.031065            0.547590          0.022695
# 497         0.044706            0.293534          0.036180
#
#      1BB_SucRaf_fitness  1BB_SucRaf_error          mutation_type
# 2              0.350548          0.067009  NotSequenced_adaptive
# 4              0.291819          0.055298  NotSequenced_adaptive
# 9              0.369475          0.069865  NotSequenced_adaptive
# 12             0.416034          0.050919  NotSequenced_adaptive
# 13             0.561952          0.051527  NotSequenced_adaptive
# 28             0.376793          0.067355  NotSequenced_adaptive
# 36            -0.514917          0.081091  NotSequenced_adaptive
# 43             0.368297          0.063284  NotSequenced_adaptive
# 52             0.351580          0.054753  NotSequenced_adaptive
# 70             0.455859          0.079631  NotSequenced_adaptive
# 102            0.403871          0.056843  NotSequenced_adaptive
# 121            0.420531          0.071594  NotSequenced_adaptive
# 128            0.348467          0.064227  NotSequenced_adaptive
# 149            0.285171          0.068892  NotSequenced_adaptive
# 151            0.356985          0.074642  NotSequenced_adaptive
# 153            0.239158          0.082391  NotSequenced_adaptive
# 180            0.480255          0.051682  NotSequenced_adaptive
# 188            0.345207          0.069228  NotSequenced_adaptive
# 200            0.241100          0.069365  NotSequenced_adaptive
# 218            0.362492          0.061489  NotSequenced_adaptive
# 220            0.388073          0.080587  NotSequenced_adaptive
# 221            0.311502          0.067697  NotSequenced_adaptive
# 225            0.364087          0.061263  NotSequenced_adaptive
# 230            0.250127          0.067563  NotSequenced_adaptive
# 231            0.314376          0.077602  NotSequenced_adaptive
# 237            0.400070          0.065773  NotSequenced_adaptive
# 243            0.374828          0.064861  NotSequenced_adaptive
# 255            0.358491          0.064355  NotSequenced_adaptive
# 279            0.274052          0.069917  NotSequenced_adaptive
# 302            0.043854          0.087139  NotSequenced_adaptive
# 308            0.373512          0.062714  NotSequenced_adaptive
# 323            0.294068          0.071903  NotSequenced_adaptive
# 327            0.404557          0.069057  NotSequenced_adaptive
# 338            0.347753          0.062513  NotSequenced_adaptive
# 364            0.377545          0.062128  NotSequenced_adaptive
# 365            0.367033          0.076292  NotSequenced_adaptive
# 371            0.170971          0.080354  NotSequenced_adaptive
# 381            0.196743          0.085202  NotSequenced_adaptive
# 408            0.516339          0.145566  NotSequenced_adaptive
# 413            0.330151          0.089907  NotSequenced_adaptive
# 421            0.250418          0.066348  NotSequenced_adaptive
# 432            0.255909          0.072903  NotSequenced_adaptive
# 450            0.544610          0.134072  NotSequenced_adaptive
# 453            0.354211          0.063548  NotSequenced_adaptive
# 466            0.460411          0.099241  NotSequenced_adaptive
# 472            0.375444          0.061949  NotSequenced_adaptive
# 493            0.368624          0.064014  NotSequenced_adaptive
# 496            0.403258          0.068000  NotSequenced_adaptive
# 497            0.327238          0.093139  NotSequenced_adaptive
#
# [49 rows x 369 columns]

# %%
fitness_data[(fitness_data['mutation_type'].isin(['ExpNeutral']))]
# Out:
# Empty DataFrame
# Columns: [barcode, gene, type, ploidy, class, additional_muts, 1.4%-R1_error, 1.4%-R1_fitness, 1.4%-R2_error, 1.4%-R2_fitness, 1.5%-R1_error, 1.5%-R1_fitness, 1.5%-R2_error, 1.5%-R2_fitness, 1.6%-R1_error, 1.6%-R1_fitness, 1.6%-R2_error, 1.6%-R2_fitness, 1.7%-R1_error, 1.7%-R1_fitness, 1.7%-R2_error, 1.7%-R2_fitness, 1.8%-R1_error, 1.8%-R1_fitness, 1.8%-R2_error, 1.8%-R2_fitness, 13.1_error, 13.1_fitness, 13.2_error, 13.2_fitness, 13.3_error, 13.3_fitness, 18.1_error, 18.1_fitness, 18.2_error, 18.2_fitness, 18.3_error, 18.3_fitness, 20.1_error, 20.1_fitness, 20.2_error, 20.2_fitness, 20.3_error, 20.3_fitness, 21.1_error, 21.1_fitness, 21.2_error, 21.2_fitness, 21.3_error, 21.3_fitness, 23.1_error, 23.1_fitness, 23.2_error, 23.2_fitness, 23.3_error, 23.3_fitness, 3.1_error, 3.1_fitness, 3.2_error, 3.2_fitness, 3.3_error, 3.3_fitness, 6.1_error, 6.1_fitness, 6.2_error, 6.2_fitness, 6.3_error, 6.3_fitness, AA_error, AA_fitness, A_error, A_fitness, BB_error, BB_fitness, B_error, B_fitness, CC_error, CC_fitness, C_error, C_fitness, DD_error, DD_fitness, D_error, D_fitness, EE_error, EE_fitness, E_error, E_fitness, FF_error, FF_fitness, F_error, F_fitness, GG_error, GG_fitness, G_error, G_fitness, H_error, H_fitness, I_error, I_fitness, ...]
# Index: []
#
# [0 rows x 351 columns]
