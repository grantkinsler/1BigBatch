# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors

from itertools import combinations, permutations
import scipy
from scipy.ndimage.filters import gaussian_filter1d
import sys
import os
import copy
atish_assay_path = 'fitness_assay_grantedits.py'
sys.path.append(os.path.dirname(os.path.expanduser(atish_assay_path)))
import fitness_assay_grantedits as atish

tools_path = '../code/tools.py'
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools

sns.set_style('white')
sns.set_style('ticks')
sns.set_color_codes()
from tools import mutant_colorset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
merged_name = 'noF_DoubleBC_merged+flaskswapcorrected_052019' 
unmerged_name = 'noF_DoubleBC_flaskswapcorrected_052019'

merged_data = p.read_csv(f'../data/BarcodeCounts_{merged_name}_withBCinfo.csv')
unmerged_data = p.read_csv(f'../data/BarcodeCounts_{unmerged_name}_withBCinfo.csv')

bad_samples = ['B3-DE1-PCRb']

# %%
old_conditions = {
                  '3':['3.1','3.2','3.3'],
                  '6':['6.1','6.2','6.3'],
                  '13':['13.1','13.2','13.3'],
                  '18':['18.1','18.2','18.3'],
                  '20':['20.1','20.2','20.3'],
                  '21':['21.1','21.2','21.3'],
                  '23':['23.1','23.2','23.3']
                 }

bigbatch_conditions = {
                        '1BB_M3':['A','B','C','D'],
                        '1BB_Baffle':['E','F'],
                        '1BB_1.4%Gluc' :['G','H'],
                        '1BB_1.8%Gluc' :['I','J'],
                        '1BB_0.2MNaCl' :['K','L'],
#                         '1BB_0.5MNaCl' :['M','N'],
#                         '1BB_0.2MNaCl' :['K'], 
                        '1BB_0.2MKCl' :['O'],
                        '1BB_0.5MKCl' :['P'],
#                         '1BB_8.5uMGdA' :['Q','R'],
#                         '1BB_17uMGdA' :['S','T'],
#                         '1BB_2ugFlu' :['U','V'],
#                         '1BB_0.5ugFlu' :['W','X'],
                        '1BB_1%Raf' :['Y','Z'],
                        '1BB_0.5%Raf' :['AA','BB'],
                        '1BB_1%Gly' :['CC','DD'],
#                         '1BB_1%EtOH' :['EE','FF'],
#                         '1BB_SucRaf' :['GG'],
                      }



conditions = {**old_conditions, **bigbatch_conditions}

just_reps = [rep for reps in conditions.values() for rep in reps]

# %%
### TECHNICAL REPLICATES

data = unmerged_data
data = data[~(data['barcode'].isin([7777777,9999999]))]
data = data.replace([np.inf, -np.inf], np.nan)
data = data.sort_values('barcode')

full_neutral_list = [17615,18486,42040,45014,58284,63611,73731,74185,80465,94896
,120600,125697,132511,134852,135750,190551,228237,238783,255561,298344
,308537,316954,317346,335717,411685,454359,469053] 

### from previous list but never has fitness above 3.5% (per gen) in any of 5000bc experiments
supergood_neutral = [17615, 24362, 42040, 71926, 72939, 73802, 80465, 109476, 113483, 
                     134852, 135750, 238783, 263665, 276406, 316954, 335717, 454359] 

### pulled from supergood list and spiked into 1BigBatch experiments
neutral_spikes = [17615,24362,42040,71926,73802,109476,113483,134852,263665,316954]

# neutrals = full_neutral_list
neutrals = list(np.unique(full_neutral_list+supergood_neutral+neutral_spikes))
neutrals = [bc for bc in neutrals if bc in data['barcode'].values]

cov_thresh = 100000
n_resamples = 50

technical_conditions = {'A':["A.DE1.PCRa","A.DE1.PCRb"],
                       'B':["B.DE1.PCRa","B.DE1.PCRb","B.DE1.PCRc","B.DE2.PCRa","B.DE3.PCRa", "B.DE4.PCRa"],
                       'C':["C.DE1.PCRa","C.DE1.PCRb","C.DE2.PCRa", "C.DE1.PCRc", "C.DE3.PCRa","C.DE3.PCRb"],
                       'D':["D.DE1.PCRa","D.DE1.PCRb"]}
        
fitnesses = {} 
for t in range(5):
    for condition in technical_conditions:
        for pair in np.unique(np.asarray(list(permutations(technical_conditions[condition]*2,2))),axis=0):
            
            flask1,de1,pcr1 = pair[0].split('.')
            flask2,de2,pcr2 = pair[1].split('.')
            
            t0 = f'{flask1}{t}-{de1}-{pcr1}'
            t1 = f'{flask2}{t+1}-{de2}-{pcr2}'
            
            if ((t0 in data.columns) and (t1 in data.columns)):

                these_times = [t0,t1]
                timepoints = [t,t+1]
                
                if np.all(np.sum(data[these_times].values,axis=0)>cov_thresh):
    
                    answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':data[these_times].values},neutralBarcodes=neutrals,
                                                lowCoverageThresh=cov_thresh,use_all_neutral=True,weightedMean=False)

                    fitnesses[f'{pair[0]}.{t}-{pair[1]}.{t+1}_original'+'_fitness'] = answer['rep1']['aveFitness']
                    fitnesses[f'{pair[0]}.{t}-{pair[1]}.{t+1}_original'+'_error'] = answer['rep1']['aveError']
                    fitnesses['barcode'] = data['barcode'].values
                    
                    t0_data = data[t0].values
                    t1_data = data[t1].values

                    
                    down_samples = [tools.downsample_single(np.asarray([t0_data,t1_data]).swapaxes(0,1),cov_thresh) for i in range(n_resamples)]

                    for sample in range(n_resamples):
#                         timepoints = [t,t+1]

                        answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':down_samples[sample]},neutralBarcodes=neutrals,
                                                        lowCoverageThresh=1,use_all_neutral=True,weightedMean=False)

                        fitnesses[f'{pair[0]}.{t}-{pair[1]}.{t+1}_resample{int(cov_thresh)}_{sample}'+'_fitness'] = answer['rep1']['aveFitness']

technical_fitness_df = p.DataFrame(fitnesses)
# Out:
# 2
# neutral reads 15412.0 28806.0
# neutral reads 15412.0 28806.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [30.18433252]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1997.0 998.0
# neutral reads 1997.0 996.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.79200788]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1977.0 976.0
# neutral reads 1977.0 976.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.49331396]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1981.0 954.0
# neutral reads 1981.0 954.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.02200115]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1967.0 950.0
# neutral reads 1967.0 949.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.82532785]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1933.0 931.0
# neutral reads 1933.0 931.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.13203184]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1918.0 958.0
# neutral reads 1918.0 958.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.93248621]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1922.0 994.0
# neutral reads 1922.0 994.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.4473439]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1955.0 1021.0
# neutral reads 1955.0 1021.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.66614654]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1958.0 939.0
# neutral reads 1958.0 939.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.82583909]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1969.0 924.0
# neutral reads 1969.0 924.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.76586852]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1938.0 985.0
# neutral reads 1938.0 985.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.5535219]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1931.0 955.0
# neutral reads 1931.0 955.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.83177609]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1989.0 964.0
# neutral reads 1989.0 964.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.12828278]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1982.0 967.0
# neutral reads 1982.0 967.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.62088793]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 

# multNoise [0.1]
# No clear inconsistencies
#
# 2
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: divide by zero encountered in power
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: invalid value encountered in multiply
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: divide by zero encountered in log
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: invalid value encountered in subtract
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:391: RuntimeWarning: divide by zero encountered in power
#   allTimeErrors = np.sqrt(np.power(allReads[repName][:,1:]/kappas,-1)
# neutral reads 1916.0 1001.0
# neutral reads 1916.0 1001.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.72482767]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2038.0 1044.0
# neutral reads 2038.0 1043.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.27123638]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1888.0 1022.0
# neutral reads 1888.0 1022.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.7074151]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1909.0 973.0
# neutral reads 1909.0 972.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.28347231]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1896.0 974.0
# neutral reads 1896.0 974.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.49480515]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2021.0 1036.0
# neutral reads 2021.0 1036.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.05957722]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1945.0 975.0
# neutral reads 1945.0 975.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.33724112]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2051.0 1049.0
# neutral reads 2051.0 1049.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.29797463]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1895.0 1011.0
# neutral reads 1895.0 1011.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.46722822]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2027.0 997.0
# neutral reads 2027.0 997.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.11170025]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1953.0 1018.0
# neutral reads 1953.0 1018.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.05873131]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2001.0 988.0
# neutral reads 2001.0 988.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.23344887]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1969.0 1023.0
# neutral reads 1969.0 1023.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.13822542]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1960.0 1052.0
# neutral reads 1960.0 1051.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.04933073]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2038.0 1037.0
# neutral reads 2038.0 1036.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.81024285]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2005.0 955.0
# neutral reads 2005.0 955.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.58687277]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1926.0 1021.0
# neutral reads 1926.0 1021.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.73104326]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2011.0 958.0
# neutral reads 2011.0 956.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.53619183]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1943.0 1017.0
# neutral reads 1943.0 1017.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.77698852]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1976.0 1054.0
# neutral reads 1976.0 1054.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.90213872]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2039.0 1019.0
# neutral reads 2039.0 1019.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.85823418]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1953.0 961.0
# neutral reads 1953.0 960.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.53798047]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1981.0 990.0
# neutral reads 1981.0 988.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.57325406]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1980.0 1009.0
# neutral reads 1980.0 1009.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.55157639]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1871.0 983.0
# neutral reads 1871.0 983.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.61861782]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1916.0 957.0
# neutral reads 1916.0 957.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.97765304]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1945.0 930.0
# neutral reads 1945.0 930.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.14035582]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1895.0 1073.0
# neutral reads 1895.0 1073.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.84407378]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1943.0 1021.0
# neutral reads 1943.0 1021.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.85361361]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2014.0 1018.0
# neutral reads 2014.0 1018.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.78449141]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1965.0 1010.0
# neutral reads 1965.0 1010.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.98785366]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1951.0 1040.0
# neutral reads 1951.0 1040.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.3920573]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1896.0 1036.0
# neutral reads 1896.0 1036.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.46382329]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1917.0 1031.0
# neutral reads 1917.0 1031.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.45274877]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 

# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 271.0 112.0
# neutral reads 258.0 95.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.38450878]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 275.0 113.0
# neutral reads 275.0 113.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.39379795]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 250.0 121.0
# neutral reads 250.0 121.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.65080811]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 236.0 115.0
# neutral reads 236.0 115.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.33043807]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 229.0 96.0
# neutral reads 216.0 84.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.40944659]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 252.0 100.0
# neutral reads 252.0 100.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.00632703]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 263.0 104.0
# neutral reads 263.0 104.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.74179149]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 242.0 123.0
# neutral reads 242.0 123.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.03614709]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 253.0 115.0
# neutral reads 248.0 107.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.25668656]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 260.0 110.0
# neutral reads 260.0 110.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.71149094]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 261.0 114.0
# neutral reads 261.0 114.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.72974658]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 248.0 123.0
# neutral reads 241.0 107.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.88102944]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 270.0 99.0
# neutral reads 270.0 99.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.02467727]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 264.0 110.0
# neutral reads 264.0 110.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.74339747]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 276.0 109.0
# neutral reads 276.0 109.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.09414686]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 238.0 121.0
# neutral reads 238.0 121.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.22683344]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 259.0 111.0
# neutral reads 259.0 111.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.93254682]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 272.0 109.0
# neutral reads 229.0 104.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.3148487]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 271.0 117.0
# neutral reads 271.0 117.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.30962101]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 225.0 139.0
# neutral reads 225.0 139.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.45306565]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 263.0 131.0
# neutral reads 263.0 131.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.65032734]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 257.0 115.0
# neutral reads 257.0 115.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.61556986]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 270.0 112.0
# neutral reads 270.0 112.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.1275174]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 235.0 143.0
# neutral reads 235.0 143.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.1642918]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 240.0 113.0
# neutral reads 240.0 113.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.80257302]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 236.0 97.0
# neutral reads 236.0 97.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.51630835]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 252.0 147.0
# neutral reads 252.0 147.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.0639023]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 249.0 108.0
# neutral reads 249.0 108.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.64622243]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 232.0 104.0
# neutral reads 232.0 104.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.34272845]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 259.0 125.0
# neutral reads 259.0 125.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.68397954]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 259.0 106.0
# neutral reads 259.0 106.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.8098628]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 253.0 106.0
# neutral reads 248.0 101.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.17376407]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 283.0 112.0
# neutral reads 283.0 112.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.95258455]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 253.0 115.0
# neutral reads 253.0 115.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.76062631]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 240.0 131.0
# neutral reads 240.0 131.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.69363666]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 256.0 133.0
# neutral reads 256.0 133.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.68618741]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 252.0 121.0
# neutral reads 252.0 121.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.76009103]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 235.0 126.0
# neutral reads 235.0 126.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.74685371]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 251.0 124.0
# neutral reads 251.0 124.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.43009928]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 235.0 128.0
# neutral reads 235.0 128.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.75977209]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 269.0 114.0
# neutral reads 269.0 114.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.7379326]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 250.0 111.0
# neutral reads 250.0 111.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.28215522]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 243.0 109.0
# neutral reads 243.0 109.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.3185533]
# multNoise [0.1]
# No clear inconsistencies

# %%
data = merged_data
data = data[~(data['barcode'].isin([7777777,9999999]))]
data = data.replace([np.inf, -np.inf], np.nan)
data = data.sort_values('barcode')

full_neutral_list = [17615,18486,42040,45014,58284,63611,73731,74185,80465,94896
,120600,125697,132511,134852,135750,190551,228237,238783,255561,298344
,308537,316954,317346,335717,411685,454359,469053] 

### from previous list but never has fitness above 3.5% (per gen) in any of 5000bc experiments
supergood_neutral = [17615, 24362, 42040, 71926, 72939, 73802, 80465, 109476, 113483, 
                     134852, 135750, 238783, 263665, 276406, 316954, 335717, 454359] 

### pulled from supergood list and spiked into 1BigBatch experiments
neutral_spikes = [17615,24362,42040,71926,73802,109476,113483,134852,263665,316954]

# neutrals = full_neutral_list
neutrals = list(np.unique(full_neutral_list+supergood_neutral+neutral_spikes))
neutrals = [bc for bc in neutrals if bc in data['barcode'].values]

# neutrals = sorted(neutrals + data[data['gene'].isin(['NotSequenced'])])

for t in range(5):
    for rep in just_reps:
        
        if rep in tools.flatten([i for i in old_conditions.values()]):
            e,r = rep.split('.')
            t0 = f'{e}-{t}-{r}'
            t1 = f'{e}-{t+1}-{r}'
        else:
            t0 = f'{rep}{t}'
            t1 = f'{rep}{t+1}'

        if ((t0 in data.columns) and (t1 in data.columns)):

            these_times = [t0,t1]
            timepoints = [t,t+1]

            if np.all(np.sum(data[these_times].values,axis=0)>cov_thresh):

                answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':data[these_times].values},neutralBarcodes=neutrals,
                                            lowCoverageThresh=cov_thresh,use_all_neutral=True,weightedMean=False)

                fitnesses[f'{rep}_T{t}to{t+1}_original'+'_fitness'] = answer['rep1']['aveFitness']
                fitnesses[f'{rep}_T{t}to{t+1}_original'+'_error'] = answer['rep1']['aveError']
                fitnesses['barcode'] = data['barcode'].values

                t0_data = data[t0].values
                t1_data = data[t1].values


                down_samples = [tools.downsample_single(np.asarray([t0_data,t1_data]).swapaxes(0,1),cov_thresh) for i in range(n_resamples)]

                for sample in range(n_resamples):
#                         timepoints = [t,t+1]

                    answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':down_samples[sample]},neutralBarcodes=neutrals,
                                                    lowCoverageThresh=1,use_all_neutral=True,weightedMean=False)

                    fitnesses[f'{rep}_T{t}to{t+1}_resample{int(cov_thresh)}_{sample}'+'_fitness'] = answer['rep1']['aveFitness']

reptime_fitness_df = p.DataFrame(fitnesses)
# Out:
# 2
# neutral reads 10696.0 1599.0
# neutral reads 10696.0 1599.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.94462541]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 504.0 236.0
# neutral reads 504.0 236.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.05287208]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 469.0 237.0
# neutral reads 469.0 237.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.26902171]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 532.0 245.0
# neutral reads 532.0 245.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [9.01395608]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 551.0 244.0
# neutral reads 551.0 244.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.4506107]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 501.0 250.0
# neutral reads 501.0 250.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.78206422]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 517.0 235.0
# neutral reads 517.0 235.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.11636171]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 569.0 256.0
# neutral reads 569.0 256.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.29611774]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 533.0 255.0
# neutral reads 533.0 255.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.99218909]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 527.0 238.0
# neutral reads 527.0 238.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.8417517]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 552.0 257.0
# neutral reads 552.0 257.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.09622195]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 515.0 223.0
# neutral reads 515.0 223.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.81637982]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 543.0 241.0
# neutral reads 543.0 241.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.3692888]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 522.0 259.0
# neutral reads 522.0 259.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.13417281]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 490.0 218.0
# neutral reads 490.0 218.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.98397372]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 549.0 248.0
# neutral reads 549.0 248.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.75389636]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 516.0 248.0
# neutral reads 516.0 248.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.25677428]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 535.0 261.0
# neutral reads 535.0 261.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.47178882]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 578.0 239.0
# neutral reads 578.0 239.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.32498938]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 497.0 265.0
# neutral reads 497.0 265.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.9744581]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 568.0 253.0
# neutral reads 568.0 253.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.09251032]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 569.0 242.0
# neutral reads 569.0 242.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.03838251]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 547.0 234.0
# neutral reads 547.0 234.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.14006197]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 599.0 248.0
# neutral reads 599.0 248.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [8.84690715]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 528.0 259.0
# neutral reads 528.0 259.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.38439647]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 573.0 236.0
# neutral reads 573.0 236.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.78033285]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 565.0 241.0
# neutral reads 565.0 241.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.49861321]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 520.0 267.0
# neutral reads 520.0 267.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.73822659]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 542.0 242.0
# neutral reads 542.0 242.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.75113603]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 533.0 250.0
# neutral reads 533.0 250.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.58946922]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 537.0 246.0
# neutral reads 537.0 246.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.65200395]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 527.0 241.0
# neutral reads 527.0 241.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.44586054]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 548.0 225.0
# neutral reads 548.0 225.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.5040882]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 577.0 248.0
# neutral reads 577.0 248.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.40709515]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 524.0 264.0
# neutral reads 524.0 264.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.0611129]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 564.0 262.0
# neutral reads 564.0 262.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.53346985]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 517.0 238.0
# neutral reads 517.0 238.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.77106336]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 533.0 256.0
# neutral reads 533.0 256.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.78131543]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 551.0 249.0
# neutral reads 551.0 249.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.02338497]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 584.0 277.0
# neutral reads 584.0 277.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.85599484]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 566.0 263.0
# neutral reads 566.0 263.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [5.97894897]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 557.0 244.0
# neutral reads 557.0 244.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.17656111]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 527.0 277.0
# neutral reads 527.0 277.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.38452746]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 566.0 244.0
# neutral reads 566.0 244.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.90234851]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: divide by zero encountered in power
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: invalid value encountered in multiply
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: divide by zero encountered in log
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: invalid value encountered in subtract
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:391: RuntimeWarning: divide by zero encountered in power
#   allTimeErrors = np.sqrt(np.power(allReads[repName][:,1:]/kappas,-1)
# neutral reads 542.0 238.0
# neutral reads 542.0 238.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.34399592]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 532.0 261.0
# neutral reads 532.0 261.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.99164441]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 557.0 241.0
# neutral reads 557.0 241.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.46105066]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 534.0 239.0
# neutral reads 534.0 239.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.63410552]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 543.0 237.0
# neutral reads 543.0 237.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [5.69994799]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 553.0 224.0
# neutral reads 553.0 224.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.50097679]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 571.0 245.0
# neutral reads 571.0 245.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.18030869]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 9781.0 1019.0
# neutral reads 9781.0 1018.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas

# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 972.0 494.0
# neutral reads 972.0 494.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.2751388]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 980.0 485.0
# neutral reads 980.0 485.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.12455118]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 989.0 461.0
# neutral reads 989.0 461.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.21300923]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 28073.0 10706.0
# neutral reads 28073.0 10706.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.83661377]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 897.0 407.0
# neutral reads 897.0 407.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.52952672]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 986.0 427.0
# neutral reads 986.0 427.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.30813217]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 916.0 414.0
# neutral reads 916.0 414.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.53652213]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 998.0 396.0
# neutral reads 998.0 396.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.38316647]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 910.0 422.0
# neutral reads 910.0 422.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.73841484]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1001.0 412.0
# neutral reads 1001.0 412.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.46403413]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 994.0 417.0
# neutral reads 994.0 417.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.61223074]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 900.0 390.0
# neutral reads 900.0 390.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.27436687]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 930.0 376.0
# neutral reads 930.0 376.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.70386526]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 979.0 415.0
# neutral reads 979.0 415.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.89295935]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 954.0 444.0
# neutral reads 954.0 444.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.09086536]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 919.0 384.0
# neutral reads 919.0 383.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.38587274]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 966.0 397.0
# neutral reads 966.0 397.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.79071096]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 961.0 383.0
# neutral reads 961.0 383.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.39280883]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 962.0 400.0
# neutral reads 962.0 400.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.79178684]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 945.0 386.0
# neutral reads 945.0 386.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.7971189]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 966.0 389.0
# neutral reads 966.0 389.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.34810252]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 954.0 402.0
# neutral reads 954.0 402.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.69548695]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 979.0 433.0
# neutral reads 979.0 433.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.12811436]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 980.0 413.0
# neutral reads 980.0 413.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.18309842]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 958.0 389.0
# neutral reads 958.0 389.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.01989758]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 926.0 395.0
# neutral reads 926.0 395.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.39585356]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 984.0 435.0
# neutral reads 984.0 435.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.59558481]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 933.0 393.0
# neutral reads 933.0 393.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.70017519]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 992.0 411.0
# neutral reads 992.0 411.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.47778114]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1007.0 427.0
# neutral reads 1007.0 427.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.66657369]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1016.0 377.0
# neutral reads 1016.0 377.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.78161059]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 964.0 390.0
# neutral reads 964.0 390.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.48884772]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 934.0 392.0
# neutral reads 934.0 392.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.61354924]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 950.0 406.0
# neutral reads 950.0 406.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.05379858]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1034.0 457.0
# neutral reads 1034.0 457.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.88126311]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1006.0 433.0
# neutral reads 1006.0 433.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.23512216]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1007.0 431.0
# neutral reads 1007.0 430.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.21390539]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 944.0 378.0
# neutral reads 944.0 378.0

# %%
data = merged_data
data = data[~(data['barcode'].isin([7777777,9999999]))]
data = data.replace([np.inf, -np.inf], np.nan)
data = data.sort_values('barcode')

full_neutral_list = [17615,18486,42040,45014,58284,63611,73731,74185,80465,94896
,120600,125697,132511,134852,135750,190551,228237,238783,255561,298344
,308537,316954,317346,335717,411685,454359,469053] 

### from previous list but never has fitness above 3.5% (per gen) in any of 5000bc experiments
supergood_neutral = [17615, 24362, 42040, 71926, 72939, 73802, 80465, 109476, 113483, 
                     134852, 135750, 238783, 263665, 276406, 316954, 335717, 454359] 

### pulled from supergood list and spiked into 1BigBatch experiments
neutral_spikes = [17615,24362,42040,71926,73802,109476,113483,134852,263665,316954]

# neutrals = full_neutral_list
neutrals = list(np.unique(full_neutral_list+supergood_neutral+neutral_spikes))
neutrals = [bc for bc in neutrals if bc in data['barcode'].values]

# neutrals = sorted(neutrals + data[data['gene'].isin(['NotSequenced'])])


for rep in just_reps:
    timepoints = []
    these_times = []
    if rep in tools.flatten([i for i in old_conditions.values()]):
        e,r = rep.split('.')
#         if e in ['13','15']:
#             timepoints.append(0)
#             these_times.append('13-0_pool')
#         else:
#             if e+'-0' in data.columns:
#                 timepoints.append(0)
#                 these_times.append(e+'-0')

        for t in range(1,5):
            if e+'-'+str(t)+'-'+r in data.columns:
                timepoints.append(t)
                these_times.append(e+'-'+str(t)+'-'+r)

    if rep in tools.flatten([i for i in bigbatch_conditions.values()]):
        for i in range(5):
            if rep+str(i) in data.columns:
                these_times.append(rep+str(i))
                timepoints.append(i)

    answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':data[these_times].values},neutralBarcodes=neutrals,
                                lowCoverageThresh=cov_thresh,use_all_neutral=True,weightedMean=False)

    fitnesses[f'{rep}_original'+'_fitness'] = answer['rep1']['aveFitness']
    fitnesses[f'{rep}_original'+'_error'] = answer['rep1']['aveError']
    fitnesses['barcode'] = data['barcode'].values

    t_data = data[these_times].values

    down_samples = [tools.downsample_single(t_data,cov_thresh) for i in range(n_resamples)]

    for sample in range(n_resamples):
#                         timepoints = [t,t+1]

        answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':down_samples[sample]},neutralBarcodes=neutrals,
                                        lowCoverageThresh=cov_thresh-1,use_all_neutral=True,weightedMean=False)

        fitnesses[f'{rep}_resample{int(cov_thresh)}_{sample}'+'_fitness'] = answer['rep1']['aveFitness']

rep_fitness_df = p.DataFrame(fitnesses)

# %%
rep_fitness_df
# Out:
#      13.11-13.12_original_error  13.11-13.12_original_fitness  \
# 0                           1.0                      0.580425
# 1                           1.0                      1.745087
# 2                           1.0                      0.312625
# 3                           1.0                      1.366066
# 4                           1.0                      1.177475
# 5                           1.0                      1.462660
# 6                           1.0                      1.373115
# 7                           1.0                      0.667436
# 8                           1.0                      1.484334
# 9                           1.0                      0.430802
# 10                          1.0                      1.426417
# 11                          1.0                      1.452079
# 12                          1.0                      1.632107
# 13                          1.0                      1.446234
# 14                          1.0                      0.624949
# 15                          1.0                      1.192964
# 16                          1.0                      0.183488
# 17                          1.0                      0.092495
# 18                          1.0                      1.011028
# 19                          1.0                      0.639256
# 20                          1.0                      0.859289
# 21                          1.0                      1.116482
# 22                          1.0                      0.971700
# 23                          1.0                      0.660267
# 24                          1.0                      1.238583
# 25                          1.0                      0.491170
# 26                          1.0                      0.492218
# 27                          1.0                      0.431870
# 28                          1.0                      0.545306
# 29                          1.0                      1.106703
# ..                          ...                           ...
# 518                         1.0                      0.116017
# 519                         1.0                           NaN
# 520                         1.0                      0.433777
# 521                         1.0                           inf
# 522                         1.0                     -0.001247
# 523                         1.0                      0.431870
# 524                         1.0                           inf
# 525                         1.0                           NaN
# 526                         1.0                          -inf
# 527                         1.0                           NaN
# 528                         1.0                      0.870125
# 529                         1.0                           NaN
# 530                         1.0                           NaN
# 531                         1.0                           NaN
# 532                         1.0                           NaN
# 533                         1.0                           NaN
# 534                         1.0                           NaN
# 535                         1.0                           NaN
# 536                         1.0                           NaN
# 537                         1.0                           NaN
# 538                         1.0                           NaN
# 539                         1.0                           NaN
# 540                         1.0                           NaN
# 541                         1.0                           NaN
# 542                         1.0                           NaN
# 543                         1.0                           NaN
# 544                         1.0                           NaN
# 545                         1.0                           NaN
# 546                         1.0                           NaN
# 547                         1.0                           NaN
#
#      13.11-13.12_resample100000_0_fitness  \
# 0                                0.368315
# 1                                1.795689
# 2                                0.379643
# 3                                1.416470
# 4                                1.206081
# 5                                1.498384
# 6                                1.273822
# 7                               -0.163564
# 8                                1.418338
# 9                                0.663115
# 10                               1.395212
# 11                               1.677373
# 12                               1.678548
# 13                               1.455272
# 14                               0.570405
# 15                               1.193803
# 16                               0.529584
# 17                              -0.042936
# 18                               1.008660
# 19                               0.844077
# 20                               1.184703
# 21                               1.107281
# 22                               1.084580
# 23                               0.750891
# 24                               1.279516
# 25                               0.586742
# 26                               0.678004
# 27                                    NaN
# 28                               0.473071
# 29                               1.246732
# ..                                    ...
# 518                             -0.792172
# 519                                   NaN
# 520                              1.030359
# 521                                   NaN
# 522                             -0.598882
# 523                                   NaN
# 524                                   NaN
# 525                                   NaN
# 526                                   NaN
# 527                                   NaN
# 528                              0.529584
# 529                                   NaN
# 530                                   NaN
# 531                                   NaN
# 532                                   NaN
# 533                                   NaN
# 534                                   NaN
# 535                                   NaN
# 536                                   NaN
# 537                                   NaN
# 538                                   NaN
# 539                                   NaN
# 540                                   NaN
# 541                                   NaN
# 542                                   NaN
# 543                                   NaN
# 544                                   NaN
# 545                                   NaN
# 546                                   NaN
# 547                                   NaN
#
#      13.11-13.12_resample100000_10_fitness  \
# 0                                 0.484976
# 1                                 1.857202
# 2                                 0.319762
# 3                                 1.469844
# 4                                 1.296556
# 5                                 1.579120
# 6                                 1.457956
# 7                                 1.589419
# 8                                 1.647080
# 9                                 0.786573
# 10                                1.494189
# 11                                1.475458
# 12                                1.769995
# 13                                1.527114
# 14                                0.941734
# 15                                1.410117
# 16                                0.048974
# 17                               -0.490022
# 18                                1.068885
# 19                                1.018611
# 20                                0.947565
# 21                                1.396147
# 22                                0.900024
# 23                                1.020097
# 24                                1.301737
# 25                                0.516782
# 26                                0.460409
# 27                                     NaN
# 28                                0.496112
# 29                                1.170897
# ..                                     ...
# 518                               0.048974
# 519                                    NaN
# 520                               0.723659
# 521                                    NaN
# 522                               0.500959
# 523                                    NaN
# 524                                    inf
# 525                                    NaN
# 526                                    NaN
# 527                                    NaN
# 528                               0.608590
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_11_fitness  \
# 0                                 0.807741
# 1                                 1.716152
# 2                                 0.291244
# 3                                 1.337717
# 4                                 1.145433
# 5                                 1.352468
# 6                                 1.400286
# 7                                 0.148496
# 8                                 1.398107
# 9                                 0.481640
# 10                                1.361059
# 11                                1.383105
# 12                                1.583746
# 13                                1.444285
# 14                                0.093233
# 15                                1.058084
# 16                                0.183181
# 17                               -0.029912
# 18                                0.783049
# 19                                0.506795
# 20                                0.978502
# 21                                1.074384
# 22                                1.061666
# 23                                0.851693
# 24                                1.229641
# 25                                0.369486
# 26                                0.488821
# 27                                     NaN
# 28                                0.618499
# 29                                1.133186
# ..                                     ...
# 518                               0.618499
# 519                                    NaN
# 520                              -0.087070
# 521                                    inf
# 522                              -0.716502
# 523                                   -inf
# 524                                    NaN
# 525                                    NaN
# 526                                    NaN
# 527                                    NaN
# 528                               1.129325
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_12_fitness  \
# 0                                 0.919396
# 1                                 1.816046
# 2                                 0.483904
# 3                                 1.427646
# 4                                 1.269635
# 5                                 1.532143
# 6                                 1.472619
# 7                                -0.139685
# 8                                 1.500843
# 9                                 0.658822
# 10                                1.486304
# 11                                1.456223
# 12                                1.714841
# 13                                1.489760
# 14                                1.052453
# 15                                1.330439
# 16                                0.185737
# 17                                0.243307
# 18                                0.899131
# 19                                0.755202
# 20                                1.081360
# 21                                1.113523
# 22                                0.877249
# 23                                0.895211
# 24                                1.334345
# 25                                0.294600
# 26                                0.454831
# 27                                     NaN
# 28                                0.728666
# 29                                1.111186
# ..                                     ...
# 518                              -0.219728
# 519                                    NaN
# 520                               0.147997
# 521                                    NaN
# 522                               0.390943
# 523                                    NaN
# 524                                    NaN
# 525                                    NaN
# 526                                    NaN
# 527                                    NaN
# 528                                   -inf
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_13_fitness  \
# 0                                 0.627690
# 1                                 1.821944
# 2                                 0.467125
# 3                                 1.473768
# 4                                 1.260025
# 5                                 1.554275
# 6                                 1.625125
# 7                                 1.290984
# 8                                 1.526009
# 9                                 0.192372
# 10                                1.537680
# 11                                1.614571
# 12                                1.748992
# 13                                1.575806
# 14                                0.494653
# 15                                1.323337
# 16                                0.127833
# 17                                0.049271
# 18                                1.149014
# 19                                0.771684
# 20                                1.276998
# 21                                1.371027
# 22                                1.131020
# 23                                0.780159
# 24                                1.346938
# 25                                0.637058
# 26                                0.643299
# 27                                     NaN
# 28                                0.474223
# 29                                1.294976
# ..                                     ...
# 518                              -1.348073
# 519                                    NaN
# 520                               0.597837
# 521                                    NaN
# 522                               0.613585
# 523                                    NaN
# 524                                    NaN
# 525                                    NaN
# 526                                   -inf
# 527                                    NaN
# 528                               0.192372
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_14_fitness  \
# 0                                 1.094056
# 1                                 1.734841
# 2                                 0.382217
# 3                                 1.372172
# 4                                 1.186345
# 5                                 1.430165
# 6                                 1.467681
# 7                                 0.747432
# 8                                 1.525633
# 9                                 0.301475
# 10                                1.480664
# 11                                1.635559
# 12                                1.663844
# 13                                1.479023
# 14                                0.645106
# 15                                1.303274
# 16                                0.204794
# 17                                0.506270
# 18                                1.072262
# 19                                0.666119
# 20                                0.934534
# 21                                0.954295
# 22                                1.017095
# 23                                0.908362
# 24                                1.260754
# 25                                0.372738
# 26                                0.620029
# 27                                     NaN
# 28                                0.648586
# 29                                1.182796
# ..                                     ...
# 518                              -0.997808
# 519                                    NaN
# 520                               0.793952
# 521                                    NaN
# 522                               0.370138
# 523                                    NaN
# 524                                    NaN
# 525                                    NaN
# 526                                    NaN
# 527                                    NaN
# 528                                   -inf
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_15_fitness  \
# 0                                 0.534839
# 1                                 1.721309
# 2                                 0.175576
# 3                                 1.344283
# 4                                 1.220310
# 5                                 1.336078
# 6                                 1.393658
# 7                                 0.960391
# 8                                 1.473289
# 9                                 0.514485
# 10                                1.457739
# 11                                1.539759
# 12                                1.643018
# 13                                1.449780
# 14                                0.737247
# 15                                1.209772
# 16                               -0.075421
# 17                                0.433229
# 18                                1.144092
# 19                                0.644538
# 20                                0.990244
# 21                                1.090299
# 22                                0.801059
# 23                                0.727715
# 24                                1.211576
# 25                                0.509079
# 26                                0.430423
# 27                                     NaN
# 28                                0.363635
# 29                                1.140049
# ..                                     ...
# 518                              -0.069229
# 519                                    NaN
# 520                               0.467914
# 521                                    NaN
# 522                              -0.409097
# 523                                   -inf
# 524                                    NaN
# 525                                    NaN
# 526                                    NaN
# 527                                    NaN
# 528                                   -inf
# 529                                    NaN
# 530                                    NaN
# 531                                    NaN
# 532                                    NaN
# 533                                    NaN
# 534                                    NaN
# 535                                    NaN
# 536                                    NaN
# 537                                    NaN
# 538                                    NaN
# 539                                    NaN
# 540                                    NaN
# 541                                    NaN
# 542                                    NaN
# 543                                    NaN
# 544                                    NaN
# 545                                    NaN
# 546                                    NaN
# 547                                    NaN
#
#      13.11-13.12_resample100000_16_fitness   ...     \
# 0                                 0.283823   ...
# 1                                 1.883976   ...
# 2                                 0.324392   ...
# 3                                 1.504592   ...
# 4                                 1.319221   ...
# 5                                 1.621659   ...
# 6                                 1.528554   ...
# 7                                 0.060680   ...
# 8                                 1.705074   ...
# 9                                 0.391109   ...
# 10                                1.610126   ...
# 11                                1.417239   ...
# 12                                1.757460   ...
# 13                                1.571272   ...
# 14                                0.466145   ...
# 15                                1.362937   ...
# 16                               -0.032578   ...
# 17                                0.480533   ...
# 18                                1.031803   ...
# 19                                0.321314   ...
# 20                                0.895238   ...
# 21                                1.150432   ...
# 22                                1.047739   ...
# 23                                0.541652   ...
# 24                                1.350880   ...
# 25                                0.721391   ...
# 26                                0.708403   ...
# 27                                    -inf   ...
# 28                                0.890586   ...
# 29                                1.230061   ...
# ..                                     ...   ...
# 518                              -0.295995   ...
# 519                                    NaN   ...
# 520                               0.930450   ...
# 521                                    NaN   ...
# 522                               0.406721   ...
# 523                                    NaN   ...
# 524                                    inf   ...
# 525                                    NaN   ...
# 526                                    NaN   ...
# 527                                    NaN   ...
# 528                               1.313443   ...
# 529                                    NaN   ...
# 530                                    NaN   ...
# 531                                    NaN   ...
# 532                                    NaN   ...
# 533                                    NaN   ...
# 534                                    NaN   ...
# 535                                    NaN   ...
# 536                                    NaN   ...
# 537                                    NaN   ...
# 538                                    NaN   ...
# 539                                    NaN   ...
# 540                                    NaN   ...
# 541                                    NaN   ...
# 542                                    NaN   ...
# 543                                    NaN   ...
# 544                                    NaN   ...
# 545                                    NaN   ...
# 546                                    NaN   ...
# 547                                    NaN   ...
#
#      Z4-Z5_resample100000_47_fitness  Z4-Z5_resample100000_48_fitness  \
# 0                           0.075057                         0.052004
# 1                           1.062401                         1.019899
# 2                          -0.003133                         0.027814
# 3                           0.874926                         0.841410
# 4                           0.724267                         0.660939
# 5                           1.048982                         1.046187
# 6                                NaN                              NaN
# 7                          -0.059229                        -0.176483
# 8                           1.162649                         1.133410
# 9                           0.070308                        -0.232300
# 10                               NaN                              NaN
# 11                               NaN                              NaN
# 12                          1.010402                         0.970233
# 13                          1.114235                         1.097698
# 14                         -0.036332                        -0.014882
# 15                          0.830139                         0.766305
# 16                         -0.055775                         0.002067
# 17                          0.066118                         0.006784
# 18                          0.838855                         0.834443
# 19                         -0.002255                        -0.007439
# 20                          0.119424                         0.034515
# 21                          0.629955                         0.571818
# 22                          0.885081                         0.867149
# 23                          0.457809                         0.447797
# 24                          0.685726                         0.653668
# 25                          0.036746                        -0.063385
# 26                          0.398929                         0.363105
# 27                               NaN                              NaN
# 28                         -0.069382                        -0.037693
# 29                               NaN                              NaN
# ..                               ...                              ...
# 518                         0.112194                        -0.198540
# 519                              NaN                              NaN
# 520                         0.048546                        -0.107379
# 526                             NaN                             NaN
# 527                             NaN                             NaN
# 528                             NaN                             NaN
# 529                             NaN                             NaN
# 530                        0.696265                        0.611869
# 531                        0.697159                        0.649691
# 532                        0.696148                        0.655663
# 533                        0.705289                        0.664790
# 534                        0.725133                        0.723357
# 535                        0.596063                        0.666009
# 536                        0.761581                        0.568264
# 537                        0.752422                        0.719650
# 538                        0.726975                        0.714470
# 539                        0.981932                        0.954809
# 540                             NaN                             NaN
# 541                        1.009087                        0.926795
# 542                        0.942490                        0.882218
# 543                        0.953402                        0.951060
# 544                        0.875658                        0.929271
# 545                             NaN                             NaN
# 546                        0.851645                        0.859649
# 547                        0.963125                        0.940681
#
#      Z4-Z5_resample100000_9_fitness  barcode
# 0                         -0.028779       53
# 1                          1.011267      151
# 2                         -0.015158      262
# 3                          0.821236      273
# 4                          0.668563      323
# 5                          1.034229      415
# 6                               NaN      499
# 7                         -0.075072      622
# 8                          1.153859      689
# 9                          0.100367      697
# 10                              NaN     1185
# 11                              NaN     1322
# 12                         0.961860     1379
# 13                         1.083537     1488
# 14                        -0.019388     1564
# 15                         0.777579     1617
# 16                         0.036797     1641
# 17                         0.088469     1683
# 18                         0.816208     1866
# 19                         0.079869     2037
# 20                         0.052339     2039
# 21                         0.631872     2288
# 22                         0.859251     2468
# 23                         0.422264     2608
# 24                         0.636256     2768
# 25                        -0.060480     2776
# 26                         0.311021     2808
# 27                              NaN     3160
# 28                        -0.105187     3250
# 29                              NaN     3298
# ..                              ...      ...
# 518                        0.022604   430247
# 519                             NaN   433489
# 520                       -0.156527   434397
# 521                             NaN   454012
# 522                        0.017972   454851
# 523                             NaN   465343
# 524                             NaN   467348
# 525                             NaN   469646
# 526                             NaN   480412
# 527                             NaN   481885
# 528                             NaN   488655
# 529                             NaN   490448
# 530                        0.675742  9000001
# 531                        0.708813  9000002
# 532                        0.678038  9000003
# 533                        0.710192  9000005
# 534                        0.586581  9000006
# 535                        0.572614  9000007
# 536                        0.599671  9000008
# 537                        0.758071  9000009
# 538                        0.683343  9000010
# 539                        0.958165  9000101
# 540                             NaN  9000103
# 541                        0.929985  9000104
# 542                        0.860601  9000105
# 543                        0.864348  9000106
# 544                        0.932230  9000107
# 545                             NaN  9000108
# 546                        0.895615  9000109
# 547                        0.914739  9000110
#
# [548 rows x 15289 columns]

# %%
full_neutral_list = [17615,18486,42040,45014,58284,63611,73731,74185,80465,94896
,120600,125697,132511,134852,135750,190551,228237,238783,255561,298344
,308537,316954,317346,335717,411685,454359,469053] 

### from previous list but never has fitness above 3.5% (per gen) in any of 5000bc experiments
supergood_neutral = [17615, 24362, 42040, 71926, 72939, 73802, 80465, 109476, 113483, 
                     134852, 135750, 238783, 263665, 276406, 316954, 335717, 454359] 

### pulled from supergood list and spiked into 1BigBatch experiments
neutral_spikes = [17615,24362,42040,71926,73802,109476,113483,134852,263665,316954]

# neutrals = full_neutral_list
neutrals = sorted(list(np.unique(full_neutral_list+supergood_neutral+neutral_spikes)))

neutrals = [bc for bc in data['barcode'].values if bc in neutrals]

# %%
tools.downsample_single(np.asarray([t0_data,t1_data]).swapaxes(0,1),1e6)[neutral_locs,:]
# Out:
# array([[152.,  76.],
#        [160.,  94.],
#        [112.,  50.],
#        [154.,  76.],
#        [150.,  59.],
#        [386., 185.],
#        [123.,  59.],
#        [359., 143.],
#        [203.,  93.],
#        [309., 154.],
#        [  4.,   0.],
#        [117.,  59.],
#        [261., 103.]])

# %%
fitnesses = {}

for flask in ['A','B','C','D']:
    for time in range(4):
        for downcov in [1e5,1e6]:
            t0_data = data[f'{flask}{time}'].values
            t1_data = data[f'{flask}{time+1}'].values

            n_samples = 50
            down_samples = [tools.downsample_single(np.asarray([t0_data,t1_data]).swapaxes(0,1),downcov) for i in range(n_samples)]

            for sample in range(n_samples):
                timepoints = [time,time+1]

                answer = atish.inferFitness(data['barcode'].values,timepoints,{'rep1':down_samples[sample]},neutralBarcodes=neutrals,
                                                lowCoverageThresh=100,use_all_neutral=True,weightedMean=False)

                fitnesses[f'{flask}{time}_{int(int(downcov)}_{sample}'+'_fitness'] = answer['rep1']['aveFitness']

fitnesses['barcode'] = data['barcode'].values
resample_df = p.DataFrame(fitnesses)

# plt.savefig(f'Alltrajectories_old+1bb_swapscorrected_reshape.pdf',bbox_inches='tight')
# Out:
# 2
# neutral reads 1489.0 937.0
# neutral reads 1489.0 935.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.52039002]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1451.0 960.0
# neutral reads 1451.0 960.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.56448631]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1445.0 928.0
# neutral reads 1445.0 928.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.46437238]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1497.0 995.0
# neutral reads 1497.0 995.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.84090094]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1417.0 1000.0
# neutral reads 1417.0 1000.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.41760845]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1447.0 946.0
# neutral reads 1447.0 946.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.61038924]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1464.0 988.0
# neutral reads 1464.0 988.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.94190793]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1464.0 991.0
# neutral reads 1464.0 990.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.32928515]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1437.0 947.0
# neutral reads 1437.0 947.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.75848052]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1455.0 1000.0
# neutral reads 1455.0 1000.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.71321742]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1538.0 974.0
# neutral reads 1538.0 974.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.54648793]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1506.0 955.0
# neutral reads 1506.0 955.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.18771862]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1455.0 966.0
# neutral reads 1455.0 966.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.30471232]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1372.0 932.0
# neutral reads 1372.0 932.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.43134251]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1465.0 958.0
# neutral reads 1465.0 958.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.30463281]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1457.0 1030.0
# neutral reads 1457.0 1030.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.3123769]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1492.0 981.0
# neutral reads 1492.0 981.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.3750648]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1449.0 1047.0
# neutral reads 1449.0 1046.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.2021959]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1437.0 998.0
# neutral reads 1437.0 998.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.38710543]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1536.0 986.0
# neutral reads 1536.0 986.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.46315058]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1436.0 963.0
# neutral reads 1436.0 963.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.83758732]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1480.0 1015.0
# neutral reads 1480.0 1015.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.21252375]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1458.0 927.0
# neutral reads 1458.0 927.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.95167838]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1497.0 951.0
# neutral reads 1497.0 951.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.94849161]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1460.0 978.0
# neutral reads 1460.0 978.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.86155242]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1528.0 1018.0
# neutral reads 1528.0 1018.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.42814562]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1503.0 1025.0
# neutral reads 1503.0 1025.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.59286594]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1473.0 1010.0
# neutral reads 1473.0 1010.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.14815404]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1519.0 964.0
# neutral reads 1519.0 962.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.03568416]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1503.0 996.0
# neutral reads 1503.0 996.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.60412158]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1478.0 966.0
# neutral reads 1478.0 966.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.48268094]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1452.0 1001.0
# neutral reads 1452.0 1001.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.60340446]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1491.0 986.0
# neutral reads 1491.0 986.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.73841713]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1497.0 975.0
# neutral reads 1457.0 919.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.03427224]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1518.0 1004.0
# neutral reads 1518.0 1004.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.64197604]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1509.0 939.0
# neutral reads 1509.0 939.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.43627512]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1443.0 981.0
# neutral reads 1443.0 981.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.65603495]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1531.0 976.0
# neutral reads 1436.0 886.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.77496253]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1427.0 950.0
# neutral reads 1427.0 950.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.24303334]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1493.0 1011.0
# neutral reads 1493.0 1011.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [3.00114088]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1461.0 980.0
# neutral reads 1461.0 980.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.16428431]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1509.0 953.0
# neutral reads 1509.0 953.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.09389845]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1494.0 1000.0
# neutral reads 1494.0 1000.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.29237719]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1487.0 996.0
# neutral reads 1487.0 995.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.09989898]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1450.0 1003.0
# neutral reads 1450.0 1003.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.55507936]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1530.0 1060.0
# neutral reads 1530.0 1060.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.21837052]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1507.0 975.0
# neutral reads 1507.0 975.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.33537644]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1461.0 978.0
# neutral reads 1461.0 978.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.42830254]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1500.0 1012.0
# neutral reads 1500.0 1012.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.87661621]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 1462.0 972.0
# neutral reads 1379.0 880.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.77908803]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14598.0 9690.0
# neutral reads 14598.0 9690.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.96786339]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14765.0 9729.0
# neutral reads 14765.0 9729.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.51640813]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14784.0 9868.0
# neutral reads 14784.0 9868.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [8.73863692]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14637.0 9998.0
# neutral reads 14637.0 9998.0
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: divide by zero encountered in power
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:219: RuntimeWarning: invalid value encountered in multiply
#   zScores = zScores*np.power(expectedReads,-0.5)
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: divide by zero encountered in log
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:386: RuntimeWarning: invalid value encountered in subtract
#   allTimeFitness = np.log(allReads[repName][:,1:]/totReads[1:])-np.log(allReads[repName][:,0:-1]/totReads[0:-1])
# /Users/grantkinsler/Documents/Stanford/Research/TheoryPaper/code/fitness_assay_grantedits.py:391: RuntimeWarning: divide by zero encountered in power
#   allTimeErrors = np.sqrt(np.power(allReads[repName][:,1:]/kappas,-1)
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [6.31503953]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14756.0 9889.0
# neutral reads 14756.0 9889.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [9.37493237]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14649.0 9928.0
# neutral reads 14649.0 9928.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [8.23671269]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14837.0 9918.0
# neutral reads 14837.0 9918.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.74013108]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14899.0 9778.0
# neutral reads 14899.0 9778.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [4.17943081]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 14854.0 9824.0
# neutral reads 14854.0 9824.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas
0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.18781153]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2489.0 1200.0
# neutral reads 2489.0 1200.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.15454588]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2561.0 1155.0
# neutral reads 2561.0 1155.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.9689455]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2493.0 1164.0
# neutral reads 2493.0 1164.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.50398614]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2493.0 1159.0
# neutral reads 2493.0 1159.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.04486039]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2545.0 1178.0
# neutral reads 2545.0 1177.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.60499385]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2570.0 1160.0
# neutral reads 2570.0 1160.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.24213975]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2553.0 1181.0
# neutral reads 2553.0 1181.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.87467655]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2577.0 1190.0
# neutral reads 2577.0 1190.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.95286273]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2383.0 1258.0
# neutral reads 2383.0 1258.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.23246366]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2483.0 1176.0
# neutral reads 2483.0 1176.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.39974583]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2571.0 1151.0
# neutral reads 2571.0 1151.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.22427589]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2482.0 1207.0
# neutral reads 2482.0 1207.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.61142172]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2461.0 1148.0
# neutral reads 2461.0 1148.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.24395107]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2483.0 1156.0
# neutral reads 2483.0 1156.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.71058731]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2530.0 1160.0
# neutral reads 2530.0 1160.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.24029465]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2578.0 1160.0
# neutral reads 2578.0 1160.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.346693]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2500.0 1164.0
# neutral reads 2500.0 1164.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.63942948]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2511.0 1159.0
# neutral reads 2511.0 1159.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.30211722]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2385.0 1145.0
# neutral reads 2385.0 1145.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.12464759]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2504.0 1201.0
# neutral reads 2504.0 1201.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.77088477]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2469.0 1217.0
# neutral reads 2469.0 1217.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.33002776]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2531.0 1168.0
# neutral reads 2531.0 1168.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.93182578]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2434.0 1185.0
# neutral reads 2434.0 1185.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [2.01940439]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2482.0 1236.0
# neutral reads 2482.0 1236.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.6602127]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2451.0 1187.0
# neutral reads 2451.0 1187.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.01819104]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2496.0 1160.0
# neutral reads 2496.0 1160.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.75573369]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2442.0 1182.0
# neutral reads 2302.0 1080.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [0.57316003]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2556.0 1148.0
# neutral reads 2556.0 1148.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.46592166]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2449.0 1218.0
# neutral reads 2449.0 1218.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.35432218]
# multNoise [0.1]
# No clear inconsistencies
#
# 2
# neutral reads 2420.0 1254.0
# neutral reads 2420.0 1254.0
# Multiplicative noise consistency checks
#
# rep1  inconsistent times:
#
# kappas [1.12910894]
# multNoise [0.1]
# No clear inconsistencies

# %%
resample_df.to_csv('../data/Fitness_Merged_1BB_M3_Resampled.csv',index=False)

# %%
resample_df
# Out:
#      A0_1000000_0_fitness  A0_1000000_10_fitness  A0_1000000_11_fitness  \
# 0                0.171060               0.137874               0.119903
# 1                0.497150               0.496052               0.506889
# 2                0.093574               0.182473               0.142764
# 3                0.505782               0.517499               0.533207
# 4                0.622275               0.611400               0.634908
# 5                0.832679               0.804443               0.822640
# 6                     NaN                    NaN                    NaN
# 7                0.084242               0.142617               0.248541
# 8                0.705860               0.672095               0.698652
# 9                0.222878               0.291194               0.299029
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                   -inf
# 12               0.617176               0.609999               0.626609
# 13               0.661431               0.624459               0.650979
# 14               0.132014               0.239953               0.171914
# 15               0.491245               0.459032               0.502484
# 16               0.081286               0.127291               0.220860
# 17              -0.090690              -0.047976               0.025424
# 540               1.385325               1.496782               1.496254
# 541               0.767197               0.826765               0.726748
# 542               0.632595               0.637086               0.639347
# 543               0.699874               0.663082               0.771294
# 544               0.942627               1.025565               0.947753
# 545                    NaN                    NaN                    NaN
# 546               0.629061               0.726920               0.779868
# 547               0.710226               0.658091               0.626586
#
#      A0_1000000_18_fitness   ...     D3_100000_47_fitness  \
# 0                 0.165028   ...                 0.623528
# 1                 0.491711   ...                 1.177642
# 2                 0.130080   ...                 0.430533
# 3                 0.483664   ...                 1.000816
# 4                 0.603471   ...                 0.920486
# 5                 0.831918   ...                 1.070940
# 6                      NaN   ...                      NaN
# 7                 0.154668   ...                 0.689023
# 8                 0.631837   ...                 1.125820
# 9                 0.247747   ...                 0.449886
# 10                     NaN   ...                      NaN
# 11                     NaN   ...                      NaN
# 12                0.611099   ...                 1.031663
# 13                0.635059   ...                 1.029025
# 14                0.175553   ...                 0.366463
# 15                0.473028   ...                 0.855316
# 16                0.227885   ...                 0.693147
# 17               -0.165159   ...                -0.156004
# 18                0.619368   ...                 0.838582
# 19                0.004932   ...                 0.577965
# 20                0.178217   ...                 0.564339
# 21                0.434385   ...                 0.856324
# 22                0.869961   ...                 0.939681
# 23                0.349529   ...                 0.511390
# 24                0.416003   ...                 0.893818
# 25                0.445072   ...                 0.682509
# 26                0.275771   ...                 0.645982
# 27                     NaN   ...                      NaN
# 28                0.232115   ...                 0.535420
# 29                    -inf   ...                      NaN
# ..                     ...   ...                      ...
# 518               0.143014   ...                 0.200671
# 519                    NaN   ...                      NaN
# 520               0.159084   ...                 0.708675
# 521                    inf   ...                      NaN
# 522              -0.045265   ...                 0.318454
# 523                    NaN   ...                      NaN
# 524                    NaN   ...                      NaN
# 525                    NaN   ...                      NaN
# 526                   -inf   ...                      NaN
# 527                    NaN   ...                      NaN
# 528               1.490745   ...                      NaN
# 529                    NaN   ...                      NaN
# 530               0.711923   ...                 0.082888
# 531               0.741794   ...                 0.732888
# 532               0.541448   ...                 0.626657
# 533               0.629139   ...                 0.635335
# 534               0.587489   ...                 0.552891
# 535               0.582834   ...                 0.621884
# 536               0.784047   ...                 0.804206
# 537               0.491249   ...                 0.583663
# 538               0.576242   ...                 0.592493
# 539               0.778980   ...                 0.756540
# 540               1.372962   ...                      NaN
# 541               0.735756   ...                 0.815566
# 542               0.670729   ...                 0.744649
# 543               0.802967   ...                 0.583663
# 544               0.866555   ...                 0.663294
# 545                    NaN   ...                      NaN
# 546               0.644526   ...                 0.658978
# 547               0.642261   ...                 0.697790
#
#      D3_100000_48_fitness  D3_100000_49_fitness  D3_100000_4_fitness  \
# 0                0.591364             -0.146183             0.302002
# 1                1.353429              0.989806             0.896472
# 2                0.545227              0.185649            -0.000809
# 3                1.142036              0.794590             0.715377
# 4                1.094184              0.637669             0.529965
# 5                1.189358              0.826718             0.682277
# 6                     NaN                   NaN                  NaN
# 7                0.805625              0.635157             0.010947
# 8                1.387402              0.947007             0.808224
# 9                0.422857             -0.161931             0.233009
# 10                    NaN                   NaN                  NaN
# 539             0.487708             0.746983  9000101
# 540             0.672443                  inf  9000103
# 541             0.644893             0.634794  9000104
# 542             0.455878             0.624522  9000105
# 543             0.605432             0.843594  9000106
# 544             0.656938             0.970910  9000107
# 545                  NaN                  NaN  9000108
# 546             0.672443             0.703547  9000109
# 547             0.684839             0.799957  9000110
#
# [548 rows x 1601 columns]

# %%
fitnesses2 = []

n_samples = 2
down_samples = [tools.downsample_single(np.asarray([t0_data,t1_data]).swapaxes(0,1),1e6) for i in range(n_samples)]

for sample in range(n_samples):
    
    log_freqs = [down_samples[sample][:,t]/np.nansum(down_samples[sample][:,t]) for t in range(2)]
    log_freqs = np.log(np.asarray(log_freqs))
    
    these_fitnesses = np.diff(log_freqs,axis=0)[0]
    
    these_fitnesses[these_fitnesses == np.inf] = np.nan
    these_fitnesses[these_fitnesses == -np.inf] = np.nan
        
    mean_neutral_deviation = np.nanmean(these_fitnesses[neutral_locs],axis=0)
#         print(condition,t,mean_neutral_deviation)
    these_fitnesses = these_fitnesses - mean_neutral_deviation

    fitnesses2.append(these_fitnesses)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:1946: RuntimeWarning: invalid value encountered in subtract
#   a = op(a[slice1], a[slice2])

# %%
flask = 'A'
time = '0'
coverage = int(1e5)
for bc in range(len(resample_df.index)):
    plt.plot(resample_df[[col for col in resample_df.columns if f'{flask}{time}_{coverage}' in col]].values[bc,:],'-o',alpha=0.3)

# %%
1e6
# Out:
# 1000000.0

# %%
swapped2 = np.asarray(fitnesses2).swapaxes(0,1)
for bc in range(swapped2.shape[0]):
    if data['barcode'].values[bc] > 9000100:
        plt.plot(swapped2[bc],'o-',color=mutant_colorset[genes[bc]],alpha=0.5)
    elif data['barcode'].values[bc] > 9000000:
        plt.plot(swapped2[bc],'o-',color='r',alpha=0.5)
    else:
        plt.plot(swapped2[bc],'o-',color=mutant_colorset[genes[bc]],alpha=0.05)

# %%
reads = down_samples[0]

coverage_cutoff = 1000
cutoff_indices = np.where(np.all(reads>coverage_cutoff,axis=1))[0]

plt.scatter(np.nanvar(swapped,axis=1)[cutoff_indices],np.nanvar(swapped2,axis=1)[cutoff_indices],alpha=0.1)
bigmin = min([min(np.nanvar(swapped,axis=1)[cutoff_indices]),min(np.nanvar(swapped2,axis=1)[cutoff_indices])])
bigmax = max([max(np.nanvar(swapped,axis=1)[cutoff_indices]),max(np.nanvar(swapped2,axis=1)[cutoff_indices])])
plt.plot([bigmin,bigmax],[bigmin,bigmax],'k--')
plt.xlim(-0.001,bigmax*1.1)
plt.ylim(-0.001,bigmax*1.1)
plt.xlabel('Variance Across 4 Resamples')
plt.ylabel('Variance Across 2 Resamples')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Degrees of freedom <= 0 for slice.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   import sys
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: Degrees of freedom <= 0 for slice.
# Text(0,0.5,'Variance Across 2 Resamples')

# %%
def sumPairs(arr, n): 
  
    # final result 
    sum = 0
    for i in range(n - 1, -1, -1): 
        sum += i*arr[i] - (n-1-i) * arr[i] 
    return sum
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
